# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import time
import re
import pickle
import tqdm

# %%
df=pd.read_excel("text-summarization.xlsx")
df.head()
# Out:
#                                                 Text  \
# 0  আমি জানি আমার এই লেখা,টির জন্য আমাকে অনেক গালম...
# 1  একটা ভাষায় তুলনামূলক ভাবে অনেক বেশি মানুষ কথা ...
# 2  আমাদের ফেব্রুয়ারি মাসটি ভাষার মাস। এর বাইরেও ত...
# 3  আমাকে যদি কেউ কখনো জিজ্ঞেস করে বাংলাদেশের সবচে...
# 4  মানুষের মুখ খুব শক্তিশালী এক জিনিস। মানুষ যেটা...
#
#                                              Summary
# 0        বাংলাদেশে কোচিং বানিজ্য বন্ধ এখন সময়ের দাবি
# 1  বাংলা ভাষার প্রযুক্তি নিয়ে আমাদের আরো অনেক বেশ...
# 2  যদি শিশুরা বই পড়ার অভ্যাস করে তাহলে সারা জীবনে...
# 3  বাংলাদেশে সব স্তরে নারীর ক্ষমতায়নের জন্য আরও অ...
# 4                          ভালো কথা বল, নয়ত চুপ থাকো

# %%
document = df['Text']
summary = df['Summary']

# %%
document[30], summary[30]
# Out:
# ('"গতরাতে আব্বু তার ফোন নিয়ে আমার কাছে এসে বললো, "বাবা, ফেইসবুকে কোন একটা পোস্টে কিভাবে প্রাইভেসি সেট করে, একটু দেখায় দেও তো"আমি তাকে একবার দেখালাম প্রসেসটা ... কিন্তু বয়সের কারণে খালি চোখে আব্বু ডান পাশের ছোট ডট দেখতে পাচ্ছিলো না ... বারবার বলতেছিলো, "কই? কই ক্লিক করবো?"প্রায় ৫ বার দেখানোর পরেও যখন আব্বু উল্টাপাল্টা ক্লিক করতেসিলো, প্রচণ্ড মেজাজ খারাপ হইলো ... আমি বেখেয়ালে একটু রাগের সুরে বললাম, "এই সিম্পল জিনিস পারতেছো না? ধুরর"এই কথাটা বলার সাথে সাথে আব্বুর মুখটা শুকনা হয়ে গেলো ... আমি সাথে সাথে বুঝতে পারলাম, মানুষটাকে আমি ছোট্ট একটা কথা দিয়ে অনেক বড় একটা কষ্ট দিয়ে ফেলসি ... \'সরি\' বলে আবার ভালোভাবে প্রসেসটা বুঝায় বললাম !!আমার ধারণা, নিজের অজান্তেই খুব ছোট ছোট কথা দিয়ে আমরা মানুষকে আঘাত করে ফেলি ... পৃথিবীতে সবাই সবকিছু পারে না ... কারো না পারা নিয়ে তার সাথে অপমানের সুরে কথা বললে সে নিজের ভেতর খুব ছোট বোধ করে ... আমার কোন অধিকার নেই কাউকে অপমান করার, কাউকে ছোট করার !!যে বাবার প্রতি আমি বিরক্ত হলাম কারণ সে সামান্য ফোন চালাতে পারছে না, সেই বাবাই ছোট বেলায় কখনো বিরক্ত হয় নি যখন আমি সামান্য হাঁটতেও পারতাম না ... দিনের পর দিন হাতে ধরে ধরে ক্লান্তিহীনভাবে শিখিয়ে গেছে ... তাকে ৫ বার বা ১০ বার ফোন চালানো শিখাতে আমার বিরক্তি আসবে কেন?নিজেকে অন্য মানুষটার জায়গায় কল্পনা করলে বুঝা যায়, কেউ আমার অপারগতা নিয়ে তাচ্ছিল্যের সুরে কথা বললে কতটা কষ্ট লাগে ... হয়তো কোন একটা ব্যাপার আমার আসলেই পারা উচিত, জানা উচিত, কিন্তু আমি পারি না অথবা জানি না ... এই ব্যর্থতা বা অপারগতার জন্য বোধহয় আমি অপমানিত হওয়া ডিজার্ভ করি না !!এই ক্ষুদ্র জীবনে ইচ্ছাকৃত কিংবা অনিচ্ছাকৃতভাবে আমার বলা কথায় যারা কষ্ট পেয়েছেন, তাদের কাছে আমি ক্ষমাপ্রার্থী ... আমি চেষ্টা করবো কখনোই কাউকে তার অজ্ঞতার জন্য ছোট না করতে !!কোন একটা বিষয় না জানাটা কোন অপরাধ না ... কিন্তু সেটা না জানার জন্য কাউকে তাচ্ছিল্য করাটা অবশ্যই অপরাধ !!আমার ধারণা, আমাদের আশেপাশে এমন কিছু মানুষ আছে যারা কথায় কথায় আমাদের ছোট করে, এই মানুষগুলোর আচরণের জন্য আমরা নিজের ভেতর ডিপ্রেসন তৈরি করে ফেলি ... যে মানুষগুলো প্রতিনিয়ত আমার অজ্ঞতা কিংবা অপারগতা নিয়ে অপমানের সুরে কথা বলে, তাদের থেকে দূরে থাকাই ভালো ... অন্যের কথার কারণে নিজের ভেতরে অপমানবোধের যে অনুভূতিটা জন্মায়, তার চেয়ে ভয়ংকর তীব্র অনুভূতি আর একটাওনেই !!',
#  'সবকিছুর সাথে আপোষ করা যায়,কিন্তু নিজের আত্মসম্মানকে যে আঘাত করে,তার সাথে আপোষ করার প্রশ্নই আসেনা ')

# %%
len(df['Text'])
# Out:
# 1026

# %%
c1 = dict(df.Text.str.split(expand=True).stack().value_counts())
c1 = dict(sorted(c1.items(), key=lambda x: x[1], reverse=True))
c2 = dict(df.Summary.str.split(expand=True).stack().value_counts())
c2 = dict(sorted(c2.items(), key=lambda x: x[1], reverse=True))

# %%
c2
# Out:
# {'না': 154,
#  'মানুষ': 70,
#  'জন্য': 63,
#  'করে': 62,
#  'ভালোবাসা': 62,
#  'না।': 56,
#  'অনেক': 54,
#  'করা': 48,
#  'মানুষের': 45,
#  'করতে': 45,
#  'আর': 45,
#  'হবে': 44,
#  'সব': 43,
#  'ভালো': 42,
#  'হয়': 39,
#  'কিছু': 39,
#  'যে': 38,
#  'সাথে': 34,
#  'এই': 33,
#  'কষ্ট': 32,
#  'এর': 32,
#  'থেকে': 32,
#  'নিজের': 32,
#  'ভালোবাসার': 32,
#  'কোনো': 31,
#  'সময়': 30,
#  'ও': 30,
#  'করার': 28,
#  'কথা': 28,
#  'হতে': 28,
#  'যায়': 28,
#  ',': 28,
#  'তার': 26,
#  'নেই': 26,
#  'একটি': 25,
#  'উচিত': 25,
#  'থাকে': 25,
#  'হয়ে': 24,
#  'আমাদের': 24,
#  'কেউ': 24,
#  'কারো': 24,
#  'প্রতি': 24,
#  'পারে': 23,
#  'প্রেম': 21,
#  '।': 21,
#  'আমরা': 21,
#  'মানুষকে': 21,
#  'উপর': 20,
#  'একজন': 20,
#  'যায়।': 20,
#  'জীবন': 20,
#  'এক': 20,
#  'হবে।': 19,
#  'হয়।': 19,
#  'নিজেকে': 19,
#  'কাউকে': 19,
#  'মন': 19,
#  'থাকা': 18,
#  'একটা': 18,
#  'কখনো': 18,
#  'তাকে': 18,
#  'এবং': 18,
#  'নিয়ে': 18,
#  'এখন': 18,
#  'করোনা': 17,
#  'এমন': 17,
#  'তা': 16,
#  'চলে': 16,
#  'সে': 16,
#  'জীবনে': 16,
#  'মধ্যে': 16,
#  'মতো': 16,
#  'শুধু': 15,
#  'যাবে': 15,
#  'সবার': 15,
#  'হচ্ছে': 15,
#  'মানে': 15,
#  'গুলো': 15,
#  'বেশি': 15,
#  'উচিত।': 14,
#  'সম্মান': 14,
#  'নেই।': 14,
#  'ভালোবাসতে': 14,
#  'খারাপ': 14,
#  'টাকা': 14,
#  'আছে': 14,
#  'দিতে': 13,
#  'জীবনের': 13,
#  'আগে': 13,
#  'হলে': 13,
#  'বলে': 13,
#  'মাঝে': 13,
#  'থাকতে': 13,
#  'কাছে': 13,
#  'যা': 13,
#  'না,': 13,
#  'দরকার': 12,
#  'নয়': 12,
#  'বলতে': 12,
#  'কিছুই': 12,
#  'সেই': 12,
#  'দিয়ে': 12,
#  'দিয়ে': 12,
#  'নারীর': 12,
#  'বা': 12,
#  'রাখতে': 12,
#  'মনে': 11,
#  'আপনি': 11,
#  'করে।': 11,
#  'কে': 11,
#  'কারণ': 11,
#  'রাখা': 11,
#  'কাজ': 11,
#  'হওয়া': 11,
#  'মেনে': 11,
#  'পাওয়া': 11,
#  'মানেই': 11,
#  'সম্পর্ক': 11,
#  'কি': 10,
#  'নিতে': 10,
#  'শেষ': 10,
#  'চেষ্টা': 10,
#  'মনের': 10,
#  'থাকলে': 10,
#  'আমি': 10,
#  'নাই।': 10,
#  'আমার': 10,
#  'থাকার': 10,
#  'সবাই': 10,
#  'দরকার।': 10,
#  'খুব': 10,
#  'নিজে': 9,
#  'চায়': 9,
#  'সময়ের': 9,
#  'প্রয়োজন': 9,
#  'সম্পর্কে': 9,
#  'যার': 9,
#  'নারীরা': 9,
#  'পেতে': 9,
#  'কষ্টের': 9,
#  'ইচ্ছা': 9,
#  'পর': 9,
#  'বন্ধু': 9,
#  'দেয়া': 9,
#  'গুরুত্ব': 9,
#  'যত': 9,
#  'বড়': 9,
#  'থাকবে': 9,
#  'মূল্য': 9,
#  'বদলে': 8,
#  'সবচেয়ে': 8,
#  'সত্যিকারের': 8,
#  'ভালো।': 8,
#  'মেয়েদের': 8,
#  'নারী': 8,
#  'অন্যের': 8,
#  'কোন': 8,
#  'নতুন': 8,
#  'দিন': 8,
#  'তাই': 8,
#  'পাশে': 8,
#  'বাংলাদেশে': 8,
#  'তাদের': 8,
#  'নষ্ট': 8,
#  'চেয়ে': 8,
#  'বই': 8,
#  'ভাইরাস': 8,
#  'যদি': 7,
#  'ঠিক': 7,
#  'নিয়ন্ত্রণ': 7,
#  'বড়': 7,
#  'সত্যি': 7,
#  'দিনশেষে': 7,
#  'প্রকাশ': 7,
#  'বলা': 7,
#  'দেশের': 7,
#  'কিন্তু': 7,
#  'লাগে': 7,
#  'দেশে': 7,
#  'দুই': 7,
#  'নাম': 7,
#  'সৌন্দর্য': 7,
#  'খুশি': 7,
#  'লেখক': 7,
#  'গেলে': 7,
#  'সুখ': 7,
#  'হয়।': 7,
#  'ভারত': 7,
#  'ছাড়া': 7,
#  'ছেলে': 7,
#  'কঠিন।': 7,
#  'বাংলাদেশ': 6,
#  'মেয়েরা': 6,
#  'একই': 6,
#  'চাওয়া': 6,
#  'আরো': 6,
#  'চেয়ে': 6,
#  'নয়।': 6,
#  'কিছুর': 6,
#  'পরিবর্তন': 6,
#  'প্রকৃত': 6,
#  'দেয়': 6,
#  'দেখা': 6,
#  'মিথ্যা': 6,
#  'আছে।': 6,
#  'করো': 6,
#  'ছেড়ে': 6,
#  'জোর': 6,
#  'আপনার': 6,
#  'দেখে': 6,
#  'প্রতিটি': 6,
#  'অল্পতেই': 6,
#  'তো': 6,
#  'পারে।': 6,
#  'লেখকের': 6,
#  'আসবে': 6,
#  'আত্মসম্মান': 6,
#  'কখনও': 6,
#  'থাকাটা': 6,
#  'যেমন': 6,
#  'ধর্ম': 6,
#  'ভুল': 6,
#  'তুমি': 6,
#  'আপনাকে': 6,
#  'দেশ': 6,
#  'খুঁজে': 6,
#  'চাইতে': 6,
#  'জিনিস': 6,
#  'বিশ্বাস': 6,
#  'পাওয়ার': 5,
#  'খরচ': 5,
#  'ভালোবেসে': 5,
#  'জরুরী।': 5,
#  'কবি': 5,
#  'শিক্ষা': 5,
#  'যাবে।': 5,
#  'যারা': 5,
#  'মায়ের': 5,
#  'পুরুষের': 5,
#  'সমাজে': 5,
#  'হলো': 5,
#  'আটকে': 5,
#  'বছরের': 5,
#  'বলার': 5,
#  'মাধ্যমে': 5,
#  'দোষ': 5,
#  'চাই।': 5,
#  'আসল': 5,
#  'দায়িত্ব': 5,
#  'দেওয়ার': 5,
#  'বুঝে': 5,
#  'একদিন': 5,
#  'যাওয়ার': 5,
#  'পৃথিবীতে': 5,
#  'তখন': 5,
#  'চোখে': 5,
#  'বেঁচে': 5,
#  'ভালোবাসায়': 5,
#  'যখন': 5,
#  'সুন্দর': 5,
#  'হয়ে': 5,
#  'নিজেদের': 5,
#  'কঠিন': 5,
#  'বাংলা': 5,
#  'ফেলে': 5,
#  'দাম': 5,
#  'হওয়ার': 5,
#  'আসে': 5,
#  'প্রশ্ন': 5,
#  'ছেলেদের': 5,
#  'ভালোবাসা।': 5,
#  'যথেষ্ট': 5,
#  'থাকে।': 5,
#  'সুখী': 5,
#  'ক্ষতি': 5,
#  'সবারই': 4,
#  'গিয়ে': 4,
#  'পাবে': 4,
#  'লুকিয়ে': 4,
#  'সন্তানের': 4,
#  'চোখের': 4,
#  'দেওয়া': 4,
#  'স্মৃতি': 4,
#  'তোমাকে': 4,
#  'হলেও': 4,
#  'আলো': 4,
#  'মজুদ': 4,
#  'আমাকে': 4,
#  'পিছনে': 4,
#  'চিন্তা': 4,
#  'অন্যকে': 4,
#  'দৃষ্টিভঙ্গি': 4,
#  'এ': 4,
#  'সকল': 4,
#  'গুলা': 4,
#  'করুন': 4,
#  'মানা': 4,
#  'সারাজীবন': 4,
#  'হার': 4,
#  'ইচ্ছে': 4,
#  'বয়স': 4,
#  'ভুলের': 4,
#  'সারারাত': 4,
#  'বেস্ট': 4,
#  'পায়': 4,
#  'নারীকে': 4,
#  'জেগে': 4,
#  'ছোটখাটো': 4,
#  'অধিকার': 4,
#  'ভালোবাসে': 4,
#  'পড়া': 4,
#  'মেয়েদের': 4,
#  'জীবনকে': 4,
#  'বড়ই': 4,
#  'গ্রহ': 4,
#  'দিয়েছে।': 4,
#  'রাখার': 4,
#  'ভাষার': 4,
#  'বসে': 4,
#  'সেটা': 4,
#  'পৃথিবীর': 4,
#  'ছোট': 4,
#  'তেমনি': 4,
#  'অপেক্ষা': 4,
#  'সকলের': 4,
#  'বিভিন্ন': 4,
#  'যাই': 4,
#  'আবেগ': 4,
#  'প্রকৃতির': 4,
#  'যাই।': 4,
#  'পরিচয়': 4,
#  'ধরে': 4,
#  'আক্রান্ত': 4,
#  'পবিত্র': 4,
#  'সঠিক': 4,
#  'থেমে': 4,
#  'আবার': 4,
#  'দূরে': 4,
#  'এখনো': 4,
#  'অতি': 4,
#  'যুদ্ধ': 4,
#  'করেছে': 4,
#  'ভুলে': 4,
#  'ভাইরাসের': 4,
#  'করতেন।': 4,
#  'যেতে': 4,
#  'পেয়ে': 4,
#  'গল্প': 4,
#  'স্কুল': 4,
#  'অবস্থায়': 4,
#  'সমাজের': 4,
#  'মহৎ': 4,
#  'যায়।': 4,
#  'সময়': 4,
#  'কাজের': 4,
#  'পড়ে': 4,
#  'স্বাধীনতা': 4,
#  'আছে,': 4,
#  'সচেতন': 4,
#  'সামনে': 4,
#  'লোক': 4,
#  'তোমার': 4,
#  'দেয়ার': 4,
#  'করি।': 4,
#  'সুযোগ': 4,
#  'দেখানো': 4,
#  'নেয়া': 4,
#  'সবচাইতে': 4,
#  'পাল্টায়': 4,
#  'চুরি': 4,
#  'ভাল': 4,
#  'দেয়।': 3,
#  'বাবা': 3,
#  'অনুভূতি': 3,
#  'যায়,': 3,
#  'তবে': 3,
#  'মর্ম': 3,
#  'কবিকে': 3,
#  'উপভোগ': 3,
#  'ঘুম': 3,
#  'মেয়ের': 3,
#  'হয়েছে।': 3,
#  'কিশোর': 3,
#  'সত্য': 3,
#  'বাংলাদেশের': 3,
#  'পথে': 3,
#  'কখন': 3,
#  'এটি': 3,
#  'স্বপ্ন': 3,
#  'মেয়ে': 3,
#  'কথা।': 3,
#  'মিষ্টি': 3,
#  'আগামী': 3,
#  'গেছে': 3,
#  'করলে': 3,
#  'মিস': 3,
#  'অভাব': 3,
#  'পাই': 3,
#  'শক্ত': 3,
#  'স্বাধীনতার': 3,
#  'টা': 3,
#  'আত্মবিশ্বাস': 3,
#  'রাখা।': 3,
#  'হোক।': 3,
#  'ই': 3,
#  'ভরসা': 3,
#  'যায়': 3,
#  'পাওয়া': 3,
#  'কথার': 3,
#  'পূরণ': 3,
#  'এখনও': 3,
#  'উপহার': 3,
#  'শক্তিশালী': 3,
#  'পার্থক্য': 3,
#  'সংসার': 3,
#  'ধরনের': 3,
#  'বঙ্গবন্ধুর': 3,
#  'মধ্যবিত্ত': 3,
#  'লাগে।': 3,
#  'বিচার': 3,
#  'কাহিনী।': 3,
#  'অনেক।': 3,
#  'নয়।': 3,
#  'জানানো': 3,
#  'নেওয়া': 3,
#  'পুরাতন': 3,
#  'আলাদা।': 3,
#  'করবেন': 3,
#  'ঘৃণা': 3,
#  'সম্ভব': 3,
#  'প্রাপ্য': 3,
#  'আল্লাহ': 3,
#  'জানতে': 3,
#  'যাকে': 3,
#  'করা।': 3,
#  'যাওয়া': 3,
#  'অতিরিক্ত': 3,
#  'প্রয়োজন।': 3,
#  'উচিৎ।': 3,
#  'লজ্জা': 3,
#  'মানুষেরই': 3,
#  'কার': 3,
#  'যথেষ্ট।': 3,
#  'মুক্তি': 3,
#  'জানে।': 3,
#  'আসল।': 3,
#  'সাহায্য': 3,
#  'একা': 3,
#  'জিনিসের': 3,
#  'বিরুদ্ধে': 3,
#  'চেনা': 3,
#  'বেপারে': 3,
#  'করেই': 3,
#  'হবার': 3,
#  'বাস্তবতা': 3,
#  'হবে,': 3,
#  'মিথ্যে': 3,
#  'হাত': 3,
#  'দুঃখ': 3,
#  'পারফেক্ট': 3,
#  'খুবই': 3,
#  'উপর।': 3,
#  'মেয়েরা': 3,
#  'করুন।': 3,
#  'লাভ': 3,
#  'কাল': 3,
#  'মানুষগুলো': 3,
#  'সারাদিন': 3,
#  'তুচ্ছ': 3,
#  'পুরুষদের': 3,
#  'বোকা': 3,
#  'পরে': 3,
#  'মাথায়': 3,
#  'মত': 3,
#  'বিয়া': 3,
#  'এটা': 3,
#  'ব্ল্যাক': 3,
#  'বানানো': 3,
#  'সিনেমা': 3,
#  'স্ট্যাটাস': 3,
#  'টেস্ট': 3,
#  'ধারনা': 3,
#  'ফল': 3,
#  'তেমন': 3,
#  'হয়েছে': 3,
#  'দুনিয়াতে': 3,
#  'পারলে': 3,
#  'পড়াশোনা': 3,
#  'ক্ষমতা': 3,
#  'যুদ্ধে': 3,
#  'বিশ্বের': 3,
#  'হাতে': 3,
#  'তে': 3,
#  'শাস্তি': 3,
#  'মেধা': 3,
#  'বাক': 3,
#  'সবাইকে': 3,
#  'ক্রিকেট': 3,
#  'ঢাকা': 3,
#  'কাজে': 3,
#  'পেলে': 3,
#  'ভীষণ': 3,
#  'বিয়ে': 3,
#  'সমান': 3,
#  'উপায়': 3,
#  'পানি': 3,
#  'চাই': 3,
#  'হিসাব': 3,
#  'লাগার': 3,
#  'আসার': 3,
#  'যাওয়া': 3,
#  'সফলতা': 3,
#  'তত': 3,
#  'মাস্ক': 3,
#  'এসে': 3,
#  'স্ট্রিং': 3,
#  'বিজ্ঞান': 3,
#  'নির্ভর': 3,
#  'চুপচাপ': 3,
#  'হল': 3,
#  'গুলোর': 3,
#  'পড়ার': 3,
#  'সৃষ্টি': 3,
#  'থাকুক': 3,
#  'কেন্দ্র': 3,
#  'অবহেলা': 3,
#  'প্রস্তুতি': 3,
#  'কিট': 3,
#  'অর্থের': 3,
#  'বলে,': 3,
#  'মূল': 3,
#  'বোঝাতে': 3,
#  'হিসাবে': 3,
#  'ভাইরাসে': 3,
#  'কাছের': 3,
#  'থেকেই': 3,
#  'বন্ধ': 3,
#  'আলোর': 3,
#  'একে': 3,
#  'শক্তি': 3,
#  'আগলে': 2,
#  'নাটকের': 2,
#  'অন্তরে': 2,
#  '৩': 2,
#  'যুগে': 2,
#  ',আমি': 2,
#  'প্রজন্ম': 2,
#  'বুদ্ধিজীবী': 2,
#  'ভাষা': 2,
#  'ইংরেজি': 2,
#  'প্রযুক্তির': 2,
#  'কমে': 2,
#  'মার্চ': 2,
#  'আকাশ': 2,
#  'দিবে': 2,
#  'শ্রদ্ধা।': 2,
#  'বাসনা।': 2,
#  'রেখেই': 2,
#  'খবর': 2,
#  ',সে': 2,
#  'যায়.': 2,
#  'ভাঙ্গার': 2,
#  'কুসংস্কার': 2,
#  'তাৎপর্য': 2,
#  'থেকেও': 2,
#  'ভোলা': 2,
#  'একসাথে': 2,
#  'চাওয়া।': 2,
#  'চেয়েও': 2,
#  'পারা': 2,
#  'বয়সে': 2,
#  'ইমোশন': 2,
#  'বৃদ্ধ': 2,
#  'ভালোবাসি': 2,
#  'কোঠাটান': 2,
#  ',এর': 2,
#  'বোঝা': 2,
#  'ছাড়াও': 2,
#  'চাবে': 2,
#  'শত': 2,
#  'আকুল': 2,
#  'সেরা': 2,
#  'অভিমানের': 2,
#  'নির্ভরশীল': 2,
#  'দেখেই': 2,
#  'সনাক্তকরনের': 2,
#  'পাবনা': 2,
#  'অবস্থান': 2,
#  'ঘরে': 2,
#  'বোঝে': 2,
#  'আবেগের': 2,
#  'বৃষ্টির': 2,
#  'কুলখানি': 2,
#  'সূর্য': 2,
#  'কেন': 2,
#  'প্রতিষ্ঠিত': 2,
#  'রাগ': 2,
#  'শক্তির': 2,
#  'মধ্য': 2,
#  'যোগ': 2,
#  'বহুবচন': 2,
#  'টেলিস্কোপের': 2,
#  'পরিবারের': 2,
#  'মাধ্যমের': 2,
#  'জেনেও': 2,
#  'আসতে': 2,
#  'ছিল': 2,
#  'গুলোকে': 2,
#  'কণিকা': 2,
#  'বুঝতে': 2,
#  'জেদ': 2,
#  'প্রোটন': 2,
#  'এনে': 2,
#  'ব্যবস্থা': 2,
#  'কম্পনের': 2,
#  'হিসেবে': 2,
#  'পদার্থের': 2,
#  'দ্বিতীয়': 2,
#  'মেশিন': 2,
#  'রাখে।': 2,
#  'ব্যাবহার': 2,
#  'মায়ায়': 2,
#  'অসাধারণ': 2,
#  'সম্মানী': 2,
#  'চিনে।': 2,
#  'মোকাবিলায়': 2,
#  'তুলে।': 2,
#  'একদিন।': 2,
#  'ছেলের': 2,
#  'দেখতে': 2,
#  'প্রেমে': 2,
#  'ভালোবাসলে': 2,
#  'বিচারিক': 2,
#  'ম্যাজিস্ট্রেটদের': 2,
#  'প্রয়োজনে': 2,
#  'কোরিয়া': 2,
#  'মৃত্যুর': 2,
#  'যাওয়া।': 2,
#  'বাঙালি': 2,
#  'শরীর': 2,
#  'জাতির': 2,
#  'দেহ': 2,
#  'করো।': 2,
#  'ছায়াপথ।': 2,
#  'দিনের': 2,
#  'কখনোই': 2,
#  'মূলত': 2,
#  'ঘুমাতে': 2,
#  'রাষ্ট্র': 2,
#  'বেশি।': 2,
#  'বললে': 2,
#  'অসুস্থ': 2,
#  'নির্দেশ': 2,
#  'ইভেন': 2,
#  'অর্থ': 2,
#  'জন্মতোই': 2,
#  'পাশের': 2,
#  'কাকে': 2,
#  'কালের': 2,
#  'সময়টা': 2,
#  'রাখি।': 2,
#  'নারীরাই': 2,
#  'জাগরণের': 2,
#  'প্রধান': 2,
#  'অন্তরায়': 2,
#  'জন্মদিন': 2,
#  'বোকামি': 2,
#  '"প্রাক্তন"': 2,
#  'কত': 2,
#  'এক্সদের': 2,
#  'ব্যাপার।': 2,
#  'দিক': 2,
#  'বোঝার': 2,
#  'বিশ্ববিদ্যালয়ের': 2,
#  'বরাদ্দ': 2,
#  'গেছে।': 2,
#  'ছাড়াই': 2,
#  'ফেরানো': 2,
#  'স্যানিটাইজার': 2,
#  'ফেসবুকে': 2,
#  'নারীদের': 2,
#  'পরিষ্কার': 2,
#  'পরিপূর্ণভাবে': 2,
#  'খেলায়': 2,
#  'সাবান': 2,
#  'ছুটে': 2,
#  'হ্যান্ড': 2,
#  'করিনি': 2,
#  'অতিমুনাফার': 2,
#  'মৃত্যু': 2,
#  'যাবেন।': 2,
#  'এমনেই': 2,
#  'ভুলার': 2,
#  'ভালোবেসেছি।': 2,
#  'মানিয়ে': 2,
#  'সংখ্যা': 2,
#  'ঘৃনা': 2,
#  'ক্রিকেটের': 2,
#  'চাঞ্চল্য': 2,
#  'শিক্ষার্থীরা': 2,
#  'আব্দুল': 2,
#  'হামিদ': 2,
#  'করি': 2,
#  'ভেজাল': 2,
#  'পাশাপাশি': 2,
#  'বয়সের': 2,
#  'কিছুকে': 2,
#  'পড়াশুনা': 2,
#  'মানায়': 2,
#  'অনেকেই': 2,
#  'জাতীয়': 2,
#  'কোচিং': 2,
#  'উপসর্গ': 2,
#  'শব্দটা': 2,
#  'ভেতরে': 2,
#  'নানা': 2,
#  'মুখ': 2,
#  'লিখে': 2,
#  'কষ্টের।': 2,
#  'চাইলে': 2,
#  'অল্প': 2,
#  'লেখা': 2,
#  'ইতিহাস': 2,
#  'জরুরি।': 2,
#  'মেরে': 2,
#  'পারছি': 2,
#  'যাওয়ায়': 2,
#  'করোনায়': 2,
#  'জাতি': 2,
#  'নেয়ার': 2,
#  'বসবাস': 2,
#  'নবাবপুর': 2,
#  'গুজব': 2,
#  'বিভ্রান্ত': 2,
#  'ব্যস্ত': 2,
#  'যত্ন': 2,
#  'চায়।': 2,
#  'গভীরতা': 2,
#  'শোনার': 2,
#  'ধর্ষিতা': 2,
#  'অতীত': 2,
#  'হারিয়ে': 2,
#  'স্যরি': 2,
#  'ঘটে': 2,
#  'করেও': 2,
#  'দিনে': 2,
#  'ধর্যের': 2,
#  'রাখুন।': 2,
#  'শিখা': 2,
#  'মনুষ্যত্বহীন': 2,
#  'হওয়া': 2,
#  'ভিতরের': 2,
#  'মানুষই': 2,
#  'ভাষণ।': 2,
#  'বিরত': 2,
#  'মেয়েকে': 2,
#  'সামান্য': 2,
#  'মার্চের': 2,
#  'মায়া': 2,
#  'গোপন': 2,
#  'ধরণ': 2,
#  'অভিযোগ।': 2,
#  'ধরণের': 2,
#  'রোমান্টিক': 2,
#  'অভিনয়': 2,
#  'মানুষগুলোর': 2,
#  'বিয়ের': 2,
#  'বাড়ির': 2,
#  'কেউই': 2,
#  'দিয়েছে': 2,
#  'আপনজন': 2,
#  'ফ্যামিলির্': 2,
#  'শিখুন।': 2,
#  'অপমান': 2,
#  'রেজাল্ট': 2,
#  'মানুষটির': 2,
#  'আজ': 2,
#  'সাদা': 2,
#  'কাজই': 2,
#  'ব্যক্তিত্ব': 2,
#  'গুছিয়ে': 2,
#  'দিবেস': 2,
#  'দিনই।': 2,
#  'ছড়িয়ে': 2,
#  'যেকোনো': 2,
#  'পারি।': 2,
#  'ভাবে': 2,
#  'শুভেচ্ছা': 2,
#  'খুন': 2,
#  'চাইলেই': 2,
#  'লাগান।': 2,
#  'ফ্রেন্ড': 2,
#  'সময়কে': 2,
#  'জন্যই': 2,
#  'জাজমেন্ট': 2,
#  'প্রিয়': 2,
#  'রক্ষা': 2,
#  '৭': 2,
#  'করানো': 2,
#  'নাই': 2,
#  'নিদৃষ্ট': 2,
#  'প্রত্যেক': 2,
#  'ঐসময়।': 2,
#  'একুশ': 2,
#  'রয়েছে।': 2,
#  'কাউকেও': 2,
#  'ধ্বংস': 2,
#  'দিবস': 2,
#  'মজাই': 2,
#  'চিঠি': 2,
#  'সবচেয়ে': 2,
#  'দিয়া': 2,
#  'সম্পত্তি': 2,
#  'অন্য': 2,
#  'নির্দিষ্ট': 2,
#  'দিন।': 2,
#  'সোজা': 2,
#  'মান': 2,
#  'নিখুঁত': 2,
#  'ভাবছি': 2,
#  'ডাক্তারের': 2,
#  'প্রভাব': 2,
#  'অপরিসীম': 2,
#  'তারাই': 2,
#  'দিয়েও': 2,
#  'অপ্রত্যাশিত': 2,
#  'ধরা': 2,
#  'ট্রাফিক': 2,
#  'সিদ্ধান্ত': 2,
#  'ততো': 2,
#  'পরীক্ষা': 2,
#  'বিচারের': 2,
#  'অপরকে': 2,
#  'মুখে': 2,
#  'পারার': 2,
#  'পারবে': 2,
#  'স্বামীর': 2,
#  'পৃথিবী': 2,
#  'বিয়ে': 2,
#  'দ্বারা': 2,
#  'পর্যন্ত': 2,
#  'পাবেন': 2,
#  'শুরু': 2,
#  'আপোষ': 2,
#  'গুন': 2,
#  'কি?': 2,
#  'বৃদ্ধি': 2,
#  'ভালোবাসাকে': 2,
#  'সময়ে': 2,
#  'পায়।': 2,
#  'বিপদে': 2,
#  'জীবনটা': 2,
#  'সৈয়দ': 2,
#  'বিদেশে': 2,
#  'ভালবাসার': 2,
#  'হয়তো': 2,
#  'নেওয়ার': 2,
#  'পুরোনো': 2,
#  'সেবা': 2,
#  'জটিল': 2,
#  'পরিশ্রম': 2,
#  'ধারণ': 2,
#  'কোনও': 2,
#  'আনন্দ': 2,
#  'শুদ্ধতম': 2,
#  'সাহিত্য': 2,
#  'নামে': 2,
#  'বাঁচতে': 2,
#  'আল্লাহর': 2,
#  'একাকিত্ব': 2,
#  'মার': 2,
#  'সর্বনাশ': 2,
#  'হউক': 2,
#  'হক': 2,
#  'চোরের': 2,
#  'হাজার': 2,
#  'নিস্পাপ': 2,
#  'লেখার': 2,
#  'চাহিদা': 2,
#  'ব্যবসা': 2,
#  'যাচ্ছি।': 2,
#  'এখানেই': 2,
#  'নিজেকেই': 2,
#  'সমস্যাটা': 2,
#  'ভেবে': 2,
#  'করেছি': 2,
#  'পাল্টা': 2,
#  'বিদেশ': 2,
#  'সারা': 2,
#  'দিকে': 2,
#  'সয়ে': 2,
#  'মাকে': 2,
#  'তাহলে': 2,
#  'হিসেব': 2,
#  'বের': 2,
#  'উঠতে': 2,
#  'পাল্টে': 2,
#  'ধুকে': 2,
#  'দুর্বোধ্য': 2,
#  'তখনই': 2,
#  'অদ্ভুত': 2,
#  'বিশ্ববিদ্যালয়': 2,
#  'সম্পদ': 2,
#  'জ্ঞান': 2,
#  'নিজেরই': 2,
#  'প্রতিনিয়ত': 2,
#  'কেও': 2,
#  'করাটা': 2,
#  'আকর্ষণ': 2,
#  'উপকার': 2,
#  'স্বীকার': 2,
#  'গল্প।': 2,
#  'তারা': 2,
#  'খানের': 2,
#  'বছর': 2,
#  'মানুুষ': 2,
#  '.': 2,
#  'অর্ধেক': 2,
#  'ভাগ্য': 2,
#  'আজম': 2,
#  'করবে।': 2,
#  'পুরুষ': 2,
#  'বিড়ম্বনা': 2,
#  'চুপ': 2,
#  'মেলাতে': 2,
#  'পেশা': 2,
#  'দাবি': 2,
#  'সমস্যার': 2,
#  'শহরে': 2,
#  'একেকটা': 2,
#  'চলার': 2,
#  'রুখে': 2,
#  'ব্যাস্ত': 2,
#  'সহজেই': 2,
#  'প্রদান': 1,
#  'রানে': 1,
#  'অন্যতম।': 1,
#  '"জিরো"': 1,
#  'মুশফিক': 1,
#  'তিনটি': 1,
#  'অনুশোচনা': 1,
#  'গবেষণা': 1,
#  'সর্বোচ্চ': 1,
#  'করেছেন।': 1,
#  'স্বাস্থ্যে': 1,
#  'আউট': 1,
#  'পশুর': 1,
#  'হলো।': 1,
#  'রিটেক': 1,
#  'দল।': 1,
#  'উপভোগে': 1,
#  'অভিযোগ': 1,
#  'ক্যাসিনো': 1,
#  'শেয়ার': 1,
#  'বাজার': 1,
#  'দুইটাই': 1,
#  'জুয়া।': 1,
#  '১০': 1,
#  'কোটি': 1,
#  'গুনতে': 1,
#  'অবশেষে': 1,
#  'পেলো': 1,
#  'লেগ': 1,
#  'স্পিনার।': 1,
#  'জ্বালিয়ে': 1,
#  'মারার': 1,
#  'মজা': 1,
#  'কোথাও': 1,
#  'কমের': 1,
#  'আকুতি।': 1,
#  'বাসের': 1,
#  'লোকাল': 1,
#  'পেরিয়ে': 1,
#  'খুশি।': 1,
#  'কলিজা': 1,
#  'দাদীকে': 1,
#  'ভোগায়।': 1,
#  'অমরত্ব': 1,
#  'নির্বাচন': 1,
#  'খালি': 1,
#  'নাচবো': 1,
#  'খাবো।': 1,
#  'পানামা': 1,
#  'সবসময়': 1,
#  'বহিরাগত।': 1,
#  'ক্ষমতাবান।': 1,
#  'গুলো।': 1,
#  'জীবন্ত': 1,
#  'করোনো': 1,
#  'গড়ে': 1,
#  'তোলার': 1,
#  'সফলতা।': 1,
#  'এরা': 1,
#  'ছাত্র': 1,
#  'কিংবদন্তী।': 1,
#  'শূন্যের': 1,
#  'সহায়তার': 1,
#  'এত্ত': 1,
#  'বোর্ড': 1,
#  'হোয়াইট': 1,
#  ...}

# %%
d1 = pd.DataFrame(c1.items(), columns=['Words', 'Count'])
d1 = d1.head(20)
d1
# Out:
#     Words  Count
# 0      না   1532
# 1     করে   1516
# 2    আমার   1143
# 3      আর   1107
# 4     আমি   1105
# 5      এই    922
# 6     তার    879
# 7     না।    770
# 8    একটা    765
# 9      যে    753
# 10   থেকে    723
# 11    হয়ে    645
# 12     সে    639
# 13    ...    628
# 14   সাথে    624
# 15   জন্য    597
# 16     কি    565
# 17  তোমার    551
# 18   করতে    534
# 19    কথা    504

# %%
d2 = pd.DataFrame(c2.items(), columns=['Words', 'Count'])
d2 = d2.head(20)
d2
# Out:
#        Words  Count
# 0         না    154
# 1      মানুষ     70
# 2       জন্য     63
# 3        করে     62
# 4   ভালোবাসা     62
# 5        না।     56
# 6       অনেক     54
# 7        করা     48
# 8    মানুষের     45
# 9       করতে     45
# 10        আর     45
# 11       হবে     44
# 12        সব     43
# 13      ভালো     42
# 14        হয়     39
# 15      কিছু     39
# 16        যে     38
# 17      সাথে     34
# 18        এই     33
# 19      কষ্ট     32

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np
prop = fm.FontProperties(fname='kalpurush.ttf')
plt.barh(d1.Words,d1.Count)
plt.yticks(d1.Words,fontproperties=prop)
plt.title('Most Frequent Word in Bengali Text')
plt.show()

# %%
plt.barh(d2.Words,d2.Count)
plt.yticks(d2.Words,fontproperties=prop)
plt.title('Most Frequent Word in Bengali Text Summary')
plt.show()

# %%
summary = summary.apply(lambda x: '<go> ' + str(x) + ' <stop>')
summary.head()
# Out:
# 0    <go> বাংলাদেশে কোচিং বানিজ্য বন্ধ এখন সময়ের দা...
# 1    <go> বাংলা ভাষার প্রযুক্তি নিয়ে আমাদের আরো অনে...
# 2    <go> যদি শিশুরা বই পড়ার অভ্যাস করে তাহলে সারা ...
# 3    <go> বাংলাদেশে সব স্তরে নারীর ক্ষমতায়নের জন্য ...
# 4                <go> ভালো কথা বল, নয়ত চুপ থাকো <stop>
# Name: Summary, dtype: object

# %%
# since < and > from default tokens cannot be removed
filters = '!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n'
oov_token = '<unk>'

# %%
document_tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token=oov_token)
summary_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters=filters, oov_token=oov_token)

# %%
document_tokenizer.fit_on_texts(document)
summary_tokenizer.fit_on_texts(summary)

# %%
inputs = document_tokenizer.texts_to_sequences(document)
targets = summary_tokenizer.texts_to_sequences(summary)

# %%
summary_tokenizer.texts_to_sequences(["বাংলাদেশে কোচিং বানিজ্য বন্ধ এখন সময়ের দাবি"])
# Out:
# [[153, 547, 942, 379, 61, 2199, 548]]

# %%
summary_tokenizer.sequences_to_texts([[153, 547, 942, 379, 61, 134, 548]])
# Out:
# ['বাংলাদেশে কোচিং বানিজ্য বন্ধ এখন সময়ের দাবি']

# %%
encoder_vocab_size = len(document_tokenizer.word_index) + 1
decoder_vocab_size = len(summary_tokenizer.word_index) + 1

encoder_vocab_size, decoder_vocab_size
# Out:
# (23995, 2814)

# %%
document_lengths = pd.Series([len(x) for x in document])
summary_lengths = pd.Series([len(x) for x in summary])

# %%
document_lengths.describe()
# Out:
# count    1026.000000
# mean      814.735867
# std       893.202858
# min        42.000000
# 25%       257.500000
# 50%       524.000000
# 75%      1029.250000
# max      8262.000000
# dtype: float64

# %%
summary_lengths.describe()
# Out:
# count    1026.000000
# mean       54.670565
# std        23.110480
# min        15.000000
# 25%        41.000000
# 50%        51.000000
# 75%        63.000000
# max       462.000000
# dtype: float64

# %%
encoder_maxlen = 250
decoder_maxlen = 75

# %%
inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs, maxlen=encoder_maxlen, padding='post', truncating='post')
targets = tf.keras.preprocessing.sequence.pad_sequences(targets, maxlen=decoder_maxlen, padding='post', truncating='post')

# %%
inputs = tf.cast(inputs, dtype=tf.int32)
targets = tf.cast(targets, dtype=tf.int32)
# Out:
# 2022-12-01 17:15:17.264429: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-01 17:15:19.727911: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:04:00.0, compute capability: 6.0

# %%
BUFFER_SIZE = 2000
BATCH_SIZE = 8

# %%
dataset = tf.data.Dataset.from_tensor_slices((inputs, targets)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def get_angles(position, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return position * angle_rates

# %%
def positional_encoding(position, d_model):
    angle_rads = get_angles(
        np.arange(position)[:, np.newaxis],
        np.arange(d_model)[np.newaxis, :],
        d_model
    )

    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

# %%
def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask

# %%
def scaled_dot_product_attention(q, k, v, mask):
    matmul_qk = tf.matmul(q, k, transpose_b=True)

    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)  

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)

    output = tf.matmul(attention_weights, v)
    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)
        
    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])
    
    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        output = self.dense(concat_attention)
            
        return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),
        tf.keras.layers.Dense(d_model)
    ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
    
    def call(self, x, training, mask):
        attn_output, _ = self.mha(x, x, x, mask)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)

        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, self.d_model)

        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)
        
    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)
    
        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training, mask)
    
        return x

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size, maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)
    
    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training, look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
    
        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, target_vocab_size, pe_input, pe_target, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, input_vocab_size, pe_input, rate)

        self.decoder = Decoder(num_layers, d_model, num_heads, dff, target_vocab_size, pe_target, rate)

        self.final_layer = tf.keras.layers.Dense(target_vocab_size)
    
    def call(self, inp, tar, training, enc_padding_mask, look_ahead_mask, dec_padding_mask):
        enc_output = self.encoder(inp, training, enc_padding_mask)

        dec_output, attention_weights = self.decoder(tar, enc_output, training, look_ahead_mask, dec_padding_mask)

        final_output = self.final_layer(dec_output)

        return final_output, attention_weights

# %%
# hyper-params
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
EPOCHS = 70

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps
    
    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')

# %%
transformer = Transformer(
    num_layers, 
    d_model, 
    num_heads, 
    dff,
    encoder_vocab_size, 
    decoder_vocab_size, 
    pe_input=encoder_vocab_size, 
    pe_target=decoder_vocab_size,
)

# %%
def create_masks(inp, tar):
    enc_padding_mask = create_padding_mask(inp)
    dec_padding_mask = create_padding_mask(inp)

    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
  
    return enc_padding_mask, combined_mask, dec_padding_mask

# %%
checkpoint_path = "checkpoints"
ckpt = tf.train.Checkpoint(transformer=transformer, optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')

# %%
@tf.function
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        predictions, _ = transformer(
            inp, tar_inp, 
            True, 
            enc_padding_mask, 
            combined_mask, 
            dec_padding_mask
        )
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)

# %%
for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()
  
    for (batch, (inp, tar)) in enumerate(dataset):
        train_step(inp, tar)
    
        # 55k samples
        # we display 3 batch results -- 0th, middle and last one (approx)
        # 55k / 64 ~ 858; 858 / 2 = 429
        if batch % 16 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1, batch, train_loss.result()))
      
    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print ('Saving checkpoint for epoch {} at {}'.format(epoch+1, ckpt_save_path))
    
    print ('Epoch {} Loss {:.4f}'.format(epoch + 1, train_loss.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 7.9766
# Epoch 1 Batch 16 Loss 7.9206
# Epoch 1 Batch 32 Loss 7.8959
# Epoch 1 Batch 48 Loss 7.8681
# Epoch 1 Batch 64 Loss 7.8391
# Epoch 1 Batch 80 Loss 7.8075
# Epoch 1 Batch 96 Loss 7.7818
# Epoch 1 Batch 112 Loss 7.7564
# Epoch 1 Batch 128 Loss 7.7327
# Epoch 1 Loss 7.7327
# Time taken for 1 epoch: 18.836956024169922 secs
#
# Epoch 2 Batch 0 Loss 7.3277
# Epoch 2 Batch 16 Loss 7.4900
# Epoch 2 Batch 32 Loss 7.4821
# Epoch 2 Batch 48 Loss 7.4710
# Epoch 2 Batch 64 Loss 7.4474
# Epoch 2 Batch 80 Loss 7.4325
# Epoch 2 Batch 96 Loss 7.4109
# Epoch 2 Batch 112 Loss 7.3858
# Epoch 2 Batch 128 Loss 7.3619
# Epoch 2 Loss 7.3619
# Time taken for 1 epoch: 3.1085941791534424 secs
#
# Epoch 3 Batch 0 Loss 7.1736
# Epoch 3 Batch 16 Loss 7.1376
# Epoch 3 Batch 32 Loss 7.1064
# Epoch 3 Batch 48 Loss 7.0748
# Epoch 3 Batch 64 Loss 7.0439
# Epoch 3 Batch 80 Loss 7.0289
# Epoch 3 Batch 96 Loss 7.0193
# Epoch 3 Batch 112 Loss 7.0016
# Epoch 3 Batch 128 Loss 6.9840
# Epoch 3 Loss 6.9840
# Time taken for 1 epoch: 3.094665765762329 secs
#
# Epoch 4 Batch 0 Loss 6.8748
# Epoch 4 Batch 16 Loss 6.7358
# Epoch 4 Batch 32 Loss 6.7304
# Epoch 4 Batch 48 Loss 6.7211
# Epoch 4 Batch 64 Loss 6.6966
# Epoch 4 Batch 80 Loss 6.6971
# Epoch 4 Batch 96 Loss 6.7007
# Epoch 4 Batch 112 Loss 6.7197
# Epoch 4 Batch 128 Loss 6.7152
# Epoch 4 Loss 6.7152
# Time taken for 1 epoch: 3.103444814682007 secs
#
# Epoch 5 Batch 0 Loss 6.7319
# Epoch 5 Batch 16 Loss 6.6021
# Epoch 5 Batch 32 Loss 6.5633
# Epoch 5 Batch 48 Loss 6.5780
# Epoch 5 Batch 64 Loss 6.5786
# Epoch 5 Batch 80 Loss 6.5893
# Epoch 5 Batch 96 Loss 6.5829
# Epoch 5 Batch 112 Loss 6.5908
# Epoch 5 Batch 128 Loss 6.5972
# Saving checkpoint for epoch 5 at checkpoints/ckpt-1
# Epoch 5 Loss 6.5972
# Time taken for 1 epoch: 3.416966199874878 secs
#
# Epoch 6 Batch 0 Loss 6.2243
# Epoch 6 Batch 16 Loss 6.4722
# Epoch 6 Batch 32 Loss 6.4957
# Epoch 6 Batch 48 Loss 6.4825
# Epoch 6 Batch 64 Loss 6.4712
# Epoch 6 Batch 80 Loss 6.4646
# Epoch 6 Batch 96 Loss 6.4678
# Epoch 6 Batch 112 Loss 6.4731
# Epoch 6 Batch 128 Loss 6.4827
# Epoch 6 Loss 6.4827
# Time taken for 1 epoch: 3.0934901237487793 secs
#
# Epoch 7 Batch 0 Loss 6.8193
# Epoch 7 Batch 16 Loss 6.3863
# Epoch 7 Batch 32 Loss 6.3506
# Epoch 7 Batch 48 Loss 6.3381
# Epoch 7 Batch 64 Loss 6.3371
# Epoch 7 Batch 80 Loss 6.3255
# Epoch 7 Batch 96 Loss 6.3267
# Epoch 7 Batch 112 Loss 6.3165
# Epoch 7 Batch 128 Loss 6.3114
# Epoch 7 Loss 6.3114
# Time taken for 1 epoch: 3.0970990657806396 secs
#
# Epoch 8 Batch 0 Loss 6.4204
# Epoch 8 Batch 16 Loss 6.1827
# Epoch 8 Batch 32 Loss 6.1328
# Epoch 8 Batch 48 Loss 6.1037
# Epoch 8 Batch 64 Loss 6.1116
# Epoch 8 Batch 80 Loss 6.0866
# Epoch 8 Batch 96 Loss 6.1015
# Epoch 8 Batch 112 Loss 6.1078
# Epoch 8 Batch 128 Loss 6.1167
# Epoch 8 Loss 6.1167
# Time taken for 1 epoch: 3.09761905670166 secs
#
# Epoch 9 Batch 0 Loss 5.7492
# Epoch 9 Batch 16 Loss 5.9218
# Epoch 9 Batch 32 Loss 5.8536
# Epoch 9 Batch 48 Loss 5.8896
# Epoch 9 Batch 64 Loss 5.8550
# Epoch 9 Batch 80 Loss 5.8577
# Epoch 9 Batch 96 Loss 5.8799
# Epoch 9 Batch 112 Loss 5.8895
# Epoch 9 Batch 128 Loss 5.9106
# Epoch 9 Loss 5.9106
# Time taken for 1 epoch: 3.1034414768218994 secs
#
# Epoch 10 Batch 0 Loss 5.6144
# Epoch 10 Batch 16 Loss 5.7536
# Epoch 10 Batch 32 Loss 5.7023
# Epoch 10 Batch 48 Loss 5.6891
# Epoch 10 Batch 64 Loss 5.6874
# Epoch 10 Batch 80 Loss 5.6780
# Epoch 10 Batch 96 Loss 5.6835
# Epoch 10 Batch 112 Loss 5.7075
# Epoch 10 Batch 128 Loss 5.7117
# Saving checkpoint for epoch 10 at checkpoints/ckpt-2
# Epoch 10 Loss 5.7117
# Time taken for 1 epoch: 3.406376361846924 secs
#
# Epoch 11 Batch 0 Loss 6.2966
# Epoch 11 Batch 16 Loss 5.5173
# Epoch 11 Batch 32 Loss 5.5225
# Epoch 11 Batch 48 Loss 5.5180
# Epoch 11 Batch 64 Loss 5.5254
# Epoch 11 Batch 80 Loss 5.5334
# Epoch 11 Batch 96 Loss 5.5380
# Epoch 11 Batch 112 Loss 5.5434
# Epoch 11 Batch 128 Loss 5.5546
# Epoch 11 Loss 5.5546
# Time taken for 1 epoch: 3.1001482009887695 secs
#
# Epoch 12 Batch 0 Loss 5.2340
# Epoch 12 Batch 16 Loss 5.3396
# Epoch 12 Batch 32 Loss 5.3348
# Epoch 12 Batch 48 Loss 5.3236
# Epoch 12 Batch 64 Loss 5.3346
# Epoch 12 Batch 80 Loss 5.3240
# Epoch 12 Batch 96 Loss 5.3358
# Epoch 12 Batch 112 Loss 5.3585
# Epoch 12 Batch 128 Loss 5.3705
# Epoch 12 Loss 5.3705
# Time taken for 1 epoch: 3.0928592681884766 secs
#
# Epoch 13 Batch 0 Loss 5.7815
# Epoch 13 Batch 16 Loss 5.1113
# Epoch 13 Batch 32 Loss 5.1384
# Epoch 13 Batch 48 Loss 5.1223
# Epoch 13 Batch 64 Loss 5.1159
# Epoch 13 Batch 80 Loss 5.1304
# Epoch 13 Batch 96 Loss 5.1356
# Epoch 13 Batch 112 Loss 5.1325
# Epoch 13 Batch 128 Loss 5.1545
# Epoch 13 Loss 5.1545
# Time taken for 1 epoch: 3.088970184326172 secs
#
# Epoch 14 Batch 0 Loss 4.6645
# Epoch 14 Batch 16 Loss 4.7676
# Epoch 14 Batch 32 Loss 4.8192
# Epoch 14 Batch 48 Loss 4.8184
# Epoch 14 Batch 64 Loss 4.8619
# Epoch 14 Batch 80 Loss 4.8664
# Epoch 14 Batch 96 Loss 4.8963
# Epoch 14 Batch 112 Loss 4.9064
# Epoch 14 Batch 128 Loss 4.9267
# Epoch 14 Loss 4.9267
# Time taken for 1 epoch: 3.1011533737182617 secs
#
# Epoch 15 Batch 0 Loss 4.7893
# Epoch 15 Batch 16 Loss 4.6429
# Epoch 15 Batch 32 Loss 4.5888
# Epoch 15 Batch 48 Loss 4.6034
# Epoch 15 Batch 64 Loss 4.6223
# Epoch 15 Batch 80 Loss 4.6292
# Epoch 15 Batch 96 Loss 4.6538
# Epoch 15 Batch 112 Loss 4.6845
# Epoch 15 Batch 128 Loss 4.7066
# Saving checkpoint for epoch 15 at checkpoints/ckpt-3
# Epoch 15 Loss 4.7066
# Time taken for 1 epoch: 3.4126532077789307 secs
#
# Epoch 16 Batch 0 Loss 4.6046
# Epoch 16 Batch 16 Loss 4.4658
# Epoch 16 Batch 32 Loss 4.4317
# Epoch 16 Batch 48 Loss 4.4265
# Epoch 16 Batch 64 Loss 4.4713
# Epoch 16 Batch 80 Loss 4.4467
# Epoch 16 Batch 96 Loss 4.4443
# Epoch 16 Batch 112 Loss 4.4434
# Epoch 16 Batch 128 Loss 4.4575
# Epoch 16 Loss 4.4575
# Time taken for 1 epoch: 3.1042768955230713 secs
#
# Epoch 17 Batch 0 Loss 3.7396
# Epoch 17 Batch 16 Loss 4.0884
# Epoch 17 Batch 32 Loss 4.1078
# Epoch 17 Batch 48 Loss 4.1284
# Epoch 17 Batch 64 Loss 4.1845
# Epoch 17 Batch 80 Loss 4.1880
# Epoch 17 Batch 96 Loss 4.2066
# Epoch 17 Batch 112 Loss 4.2049
# Epoch 17 Batch 128 Loss 4.2077
# Epoch 17 Loss 4.2077
# Time taken for 1 epoch: 3.1015961170196533 secs
#
# Epoch 18 Batch 0 Loss 4.0317
# Epoch 18 Batch 16 Loss 3.8759
# Epoch 18 Batch 32 Loss 3.8810
# Epoch 18 Batch 48 Loss 3.8497
# Epoch 18 Batch 64 Loss 3.8893
# Epoch 18 Batch 80 Loss 3.9099
# Epoch 18 Batch 96 Loss 3.8932
# Epoch 18 Batch 112 Loss 3.9050
# Epoch 18 Batch 128 Loss 3.9287
# Epoch 18 Loss 3.9287
# Time taken for 1 epoch: 3.0932741165161133 secs
#
# Epoch 19 Batch 0 Loss 3.6808
# Epoch 19 Batch 16 Loss 3.5512
# Epoch 19 Batch 32 Loss 3.5962
# Epoch 19 Batch 48 Loss 3.5853
# Epoch 19 Batch 64 Loss 3.5745
# Epoch 19 Batch 80 Loss 3.6167
# Epoch 19 Batch 96 Loss 3.6359
# Epoch 19 Batch 112 Loss 3.6422
# Epoch 19 Batch 128 Loss 3.6415
# Epoch 19 Loss 3.6415
# Time taken for 1 epoch: 3.0886406898498535 secs
#
# Epoch 20 Batch 0 Loss 2.8850
# Epoch 20 Batch 16 Loss 3.2255
# Epoch 20 Batch 32 Loss 3.2092
# Epoch 20 Batch 48 Loss 3.1936
# Epoch 20 Batch 64 Loss 3.1989
# Epoch 20 Batch 80 Loss 3.2388
# Epoch 20 Batch 96 Loss 3.2478
# Epoch 20 Batch 112 Loss 3.2783
# Epoch 20 Batch 128 Loss 3.3337
# Saving checkpoint for epoch 20 at checkpoints/ckpt-4
# Epoch 20 Loss 3.3337
# Time taken for 1 epoch: 3.413616180419922 secs
#
# Epoch 21 Batch 0 Loss 3.2106
# Epoch 21 Batch 16 Loss 2.9854
# Epoch 21 Batch 32 Loss 2.9921
# Epoch 21 Batch 48 Loss 3.0070
# Epoch 21 Batch 64 Loss 3.0298
# Epoch 21 Batch 80 Loss 3.0372
# Epoch 21 Batch 96 Loss 3.0335
# Epoch 21 Batch 112 Loss 3.0390
# Epoch 21 Batch 128 Loss 3.0709
# Epoch 21 Loss 3.0709
# Time taken for 1 epoch: 3.108102321624756 secs
#
# Epoch 22 Batch 0 Loss 2.3081
# Epoch 22 Batch 16 Loss 2.6639
# Epoch 22 Batch 32 Loss 2.6707
# Epoch 22 Batch 48 Loss 2.6640
# Epoch 22 Batch 64 Loss 2.7239
# Epoch 22 Batch 80 Loss 2.7241
# Epoch 22 Batch 96 Loss 2.7486
# Epoch 22 Batch 112 Loss 2.7553
# Epoch 22 Batch 128 Loss 2.7784
# Epoch 22 Loss 2.7784
# Time taken for 1 epoch: 3.0950746536254883 secs
#
# Epoch 23 Batch 0 Loss 2.3178
# Epoch 23 Batch 16 Loss 2.3612
# Epoch 23 Batch 32 Loss 2.3459
# Epoch 23 Batch 48 Loss 2.3550
# Epoch 23 Batch 64 Loss 2.3931
# Epoch 23 Batch 80 Loss 2.4187
# Epoch 23 Batch 96 Loss 2.4136
# Epoch 23 Batch 112 Loss 2.4318
# Epoch 23 Batch 128 Loss 2.4448
# Epoch 23 Loss 2.4448
# Time taken for 1 epoch: 3.0984609127044678 secs
#
# Epoch 24 Batch 0 Loss 2.2160
# Epoch 24 Batch 16 Loss 1.9712
# Epoch 24 Batch 32 Loss 2.0050
# Epoch 24 Batch 48 Loss 2.0560
# Epoch 24 Batch 64 Loss 2.0683
# Epoch 24 Batch 80 Loss 2.0730
# Epoch 24 Batch 96 Loss 2.1096
# Epoch 24 Batch 112 Loss 2.1287
# Epoch 24 Batch 128 Loss 2.1638
# Epoch 24 Loss 2.1638
# Time taken for 1 epoch: 3.0951473712921143 secs
#
# Epoch 25 Batch 0 Loss 1.7465
# Epoch 25 Batch 16 Loss 1.6791
# Epoch 25 Batch 32 Loss 1.7450
# Epoch 25 Batch 48 Loss 1.7414
# Epoch 25 Batch 64 Loss 1.7943
# Epoch 25 Batch 80 Loss 1.8097
# Epoch 25 Batch 96 Loss 1.8358
# Epoch 25 Batch 112 Loss 1.8597
# Epoch 25 Batch 128 Loss 1.8838
# Saving checkpoint for epoch 25 at checkpoints/ckpt-5
# Epoch 25 Loss 1.8838
# Time taken for 1 epoch: 3.4189414978027344 secs
#
# Epoch 26 Batch 0 Loss 1.4438
# Epoch 26 Batch 16 Loss 1.4796
# Epoch 26 Batch 32 Loss 1.5352
# Epoch 26 Batch 48 Loss 1.5693
# Epoch 26 Batch 64 Loss 1.5870
# Epoch 26 Batch 80 Loss 1.6148
# Epoch 26 Batch 96 Loss 1.6395
# Epoch 26 Batch 112 Loss 1.6595
# Epoch 26 Batch 128 Loss 1.6735
# Epoch 26 Loss 1.6735
# Time taken for 1 epoch: 3.1063337326049805 secs
#
# Epoch 27 Batch 0 Loss 0.8828
# Epoch 27 Batch 16 Loss 1.2864
# Epoch 27 Batch 32 Loss 1.2750
# Epoch 27 Batch 48 Loss 1.2703
# Epoch 27 Batch 64 Loss 1.3092
# Epoch 27 Batch 80 Loss 1.3283
# Epoch 27 Batch 96 Loss 1.3437
# Epoch 27 Batch 112 Loss 1.3687
# Epoch 27 Batch 128 Loss 1.3819
# Epoch 27 Loss 1.3819
# Time taken for 1 epoch: 3.092642307281494 secs
#
# Epoch 28 Batch 0 Loss 0.8094
# Epoch 28 Batch 16 Loss 1.1514
# Epoch 28 Batch 32 Loss 1.1072
# Epoch 28 Batch 48 Loss 1.0932
# Epoch 28 Batch 64 Loss 1.1072
# Epoch 28 Batch 80 Loss 1.1558
# Epoch 28 Batch 96 Loss 1.2010
# Epoch 28 Batch 112 Loss 1.2200
# Epoch 28 Batch 128 Loss 1.2353
# Epoch 28 Loss 1.2353
# Time taken for 1 epoch: 3.098452568054199 secs
#
# Epoch 29 Batch 0 Loss 1.2556
# Epoch 29 Batch 16 Loss 0.8774
# Epoch 29 Batch 32 Loss 0.8899
# Epoch 29 Batch 48 Loss 0.9076
# Epoch 29 Batch 64 Loss 0.9203
# Epoch 29 Batch 80 Loss 0.9465
# Epoch 29 Batch 96 Loss 0.9810
# Epoch 29 Batch 112 Loss 1.0104
# Epoch 29 Batch 128 Loss 1.0354
# Epoch 29 Loss 1.0354
# Time taken for 1 epoch: 3.098802089691162 secs
#
# Epoch 30 Batch 0 Loss 0.8688
# Epoch 30 Batch 16 Loss 0.8443
# Epoch 30 Batch 32 Loss 0.8246
# Epoch 30 Batch 48 Loss 0.8449
# Epoch 30 Batch 64 Loss 0.8400
# Epoch 30 Batch 80 Loss 0.8589
# Epoch 30 Batch 96 Loss 0.8848
# Epoch 30 Batch 112 Loss 0.9028
# Epoch 30 Batch 128 Loss 0.9324
# Saving checkpoint for epoch 30 at checkpoints/ckpt-6
# Epoch 30 Loss 0.9324
# Time taken for 1 epoch: 3.424022912979126 secs
#
# Epoch 31 Batch 0 Loss 0.9873
# Epoch 31 Batch 16 Loss 0.7075
# Epoch 31 Batch 32 Loss 0.7241
# Epoch 31 Batch 48 Loss 0.7393
# Epoch 31 Batch 64 Loss 0.7499
# Epoch 31 Batch 80 Loss 0.7662
# Epoch 31 Batch 96 Loss 0.7888
# Epoch 31 Batch 112 Loss 0.8192
# Epoch 31 Batch 128 Loss 0.8407
# Epoch 31 Loss 0.8407
# Time taken for 1 epoch: 3.0967869758605957 secs
#
# Epoch 32 Batch 0 Loss 0.7701
# Epoch 32 Batch 16 Loss 0.6250
# Epoch 32 Batch 32 Loss 0.6109
# Epoch 32 Batch 48 Loss 0.6130
# Epoch 32 Batch 64 Loss 0.6341
# Epoch 32 Batch 80 Loss 0.6693
# Epoch 32 Batch 96 Loss 0.6965
# Epoch 32 Batch 112 Loss 0.7288
# Epoch 32 Batch 128 Loss 0.7509
# Epoch 32 Loss 0.7509
# Time taken for 1 epoch: 3.096252202987671 secs
#
# Epoch 33 Batch 0 Loss 0.4486
# Epoch 33 Batch 16 Loss 0.5864
# Epoch 33 Batch 32 Loss 0.6186
# Epoch 33 Batch 48 Loss 0.5876
# Epoch 33 Batch 64 Loss 0.5754
# Epoch 33 Batch 80 Loss 0.5812
# Epoch 33 Batch 96 Loss 0.5940
# Epoch 33 Batch 112 Loss 0.6022
# Epoch 33 Batch 128 Loss 0.6270
# Epoch 33 Loss 0.6270
# Time taken for 1 epoch: 3.0952255725860596 secs
#
# Epoch 34 Batch 0 Loss 0.1705
# Epoch 34 Batch 16 Loss 0.4242
# Epoch 34 Batch 32 Loss 0.4522
# Epoch 34 Batch 48 Loss 0.4593
# Epoch 34 Batch 64 Loss 0.4878
# Epoch 34 Batch 80 Loss 0.4976
# Epoch 34 Batch 96 Loss 0.5206
# Epoch 34 Batch 112 Loss 0.5312
# Epoch 34 Batch 128 Loss 0.5592
# Epoch 34 Loss 0.5592
# Time taken for 1 epoch: 3.1015477180480957 secs
#
# Epoch 35 Batch 0 Loss 0.3454
# Epoch 35 Batch 16 Loss 0.5414
# Epoch 35 Batch 32 Loss 0.5222
# Epoch 35 Batch 48 Loss 0.5173
# Epoch 35 Batch 64 Loss 0.5075
# Epoch 35 Batch 80 Loss 0.5055
# Epoch 35 Batch 96 Loss 0.5063
# Epoch 35 Batch 112 Loss 0.5123
# Epoch 35 Batch 128 Loss 0.5263
# Saving checkpoint for epoch 35 at checkpoints/ckpt-7
# Epoch 35 Loss 0.5263
# Time taken for 1 epoch: 3.4057164192199707 secs
#
# Epoch 36 Batch 0 Loss 0.2191
# Epoch 36 Batch 16 Loss 0.4305
# Epoch 36 Batch 32 Loss 0.3965
# Epoch 36 Batch 48 Loss 0.3938
# Epoch 36 Batch 64 Loss 0.3892
# Epoch 36 Batch 80 Loss 0.3937
# Epoch 36 Batch 96 Loss 0.3996
# Epoch 36 Batch 112 Loss 0.4165
# Epoch 36 Batch 128 Loss 0.4226
# Epoch 36 Loss 0.4226
# Time taken for 1 epoch: 3.0924341678619385 secs
#
# Epoch 37 Batch 0 Loss 0.1898
# Epoch 37 Batch 16 Loss 0.3693
# Epoch 37 Batch 32 Loss 0.3749
# Epoch 37 Batch 48 Loss 0.3714
# Epoch 37 Batch 64 Loss 0.3701
# Epoch 37 Batch 80 Loss 0.3712
# Epoch 37 Batch 96 Loss 0.3786
# Epoch 37 Batch 112 Loss 0.3924
# Epoch 37 Batch 128 Loss 0.4111
# Epoch 37 Loss 0.4111
# Time taken for 1 epoch: 3.103043794631958 secs
#
# Epoch 38 Batch 0 Loss 0.2976
# Epoch 38 Batch 16 Loss 0.2839
# Epoch 38 Batch 32 Loss 0.2920
# Epoch 38 Batch 48 Loss 0.3217
# Epoch 38 Batch 64 Loss 0.3328
# Epoch 38 Batch 80 Loss 0.3389
# Epoch 38 Batch 96 Loss 0.3511
# Epoch 38 Batch 112 Loss 0.3639
# Epoch 38 Batch 128 Loss 0.3723
# Epoch 38 Loss 0.3723
# Time taken for 1 epoch: 3.1035985946655273 secs
#
# Epoch 39 Batch 0 Loss 0.2949
# Epoch 39 Batch 16 Loss 0.3127
# Epoch 39 Batch 32 Loss 0.3294
# Epoch 39 Batch 48 Loss 0.3288
# Epoch 39 Batch 64 Loss 0.3275
# Epoch 39 Batch 80 Loss 0.3271
# Epoch 39 Batch 96 Loss 0.3244
# Epoch 39 Batch 112 Loss 0.3366
# Epoch 39 Batch 128 Loss 0.3454
# Epoch 39 Loss 0.3454
# Time taken for 1 epoch: 3.0894973278045654 secs
#
# Epoch 40 Batch 0 Loss 0.4223
# Epoch 40 Batch 16 Loss 0.2455
# Epoch 40 Batch 32 Loss 0.2569
# Epoch 40 Batch 48 Loss 0.2512
# Epoch 40 Batch 64 Loss 0.2688
# Epoch 40 Batch 80 Loss 0.2828
# Epoch 40 Batch 96 Loss 0.3007
# Epoch 40 Batch 112 Loss 0.3166
# Epoch 40 Batch 128 Loss 0.3260
# Saving checkpoint for epoch 40 at checkpoints/ckpt-8
# Epoch 40 Loss 0.3260
# Time taken for 1 epoch: 3.388183832168579 secs
#
# Epoch 41 Batch 0 Loss 0.4154
# Epoch 41 Batch 16 Loss 0.3416
# Epoch 41 Batch 32 Loss 0.3091
# Epoch 41 Batch 48 Loss 0.2984
# Epoch 41 Batch 64 Loss 0.2825
# Epoch 41 Batch 80 Loss 0.2705
# Epoch 41 Batch 96 Loss 0.2707
# Epoch 41 Batch 112 Loss 0.2698
# Epoch 41 Batch 128 Loss 0.2768
# Epoch 41 Loss 0.2768
# Time taken for 1 epoch: 3.098663091659546 secs
#
# Epoch 42 Batch 0 Loss 0.2214
# Epoch 42 Batch 16 Loss 0.2179
# Epoch 42 Batch 32 Loss 0.2033
# Epoch 42 Batch 48 Loss 0.2105
# Epoch 42 Batch 64 Loss 0.2195
# Epoch 42 Batch 80 Loss 0.2303
# Epoch 42 Batch 96 Loss 0.2438
# Epoch 42 Batch 112 Loss 0.2550
# Epoch 42 Batch 128 Loss 0.2633
# Epoch 42 Loss 0.2633
# Time taken for 1 epoch: 3.09146785736084 secs
#
# Epoch 43 Batch 0 Loss 0.2539
# Epoch 43 Batch 16 Loss 0.2105
# Epoch 43 Batch 32 Loss 0.2294
# Epoch 43 Batch 48 Loss 0.2249
# Epoch 43 Batch 64 Loss 0.2406
# Epoch 43 Batch 80 Loss 0.2349
# Epoch 43 Batch 96 Loss 0.2406
# Epoch 43 Batch 112 Loss 0.2492
# Epoch 43 Batch 128 Loss 0.2601
# Epoch 43 Loss 0.2601
# Time taken for 1 epoch: 3.1009557247161865 secs
#
# Epoch 44 Batch 0 Loss 0.2673
# Epoch 44 Batch 16 Loss 0.2114
# Epoch 44 Batch 32 Loss 0.2414
# Epoch 44 Batch 48 Loss 0.2374
# Epoch 44 Batch 64 Loss 0.2318
# Epoch 44 Batch 80 Loss 0.2372
# Epoch 44 Batch 96 Loss 0.2385
# Epoch 44 Batch 112 Loss 0.2432
# Epoch 44 Batch 128 Loss 0.2466
# Epoch 44 Loss 0.2466
# Time taken for 1 epoch: 3.1162917613983154 secs
#
# Epoch 45 Batch 0 Loss 0.1817
# Epoch 45 Batch 16 Loss 0.1538
# Epoch 45 Batch 32 Loss 0.1809
# Epoch 45 Batch 48 Loss 0.1963
# Epoch 45 Batch 64 Loss 0.1965
# Epoch 45 Batch 80 Loss 0.2117
# Epoch 45 Batch 96 Loss 0.2150
# Epoch 45 Batch 112 Loss 0.2208
# Epoch 45 Batch 128 Loss 0.2246
# Saving checkpoint for epoch 45 at checkpoints/ckpt-9
# Epoch 45 Loss 0.2246
# Time taken for 1 epoch: 3.4033567905426025 secs
#
# Epoch 46 Batch 0 Loss 0.1109
# Epoch 46 Batch 16 Loss 0.1973
# Epoch 46 Batch 32 Loss 0.1877
# Epoch 46 Batch 48 Loss 0.1870
# Epoch 46 Batch 64 Loss 0.1839
# Epoch 46 Batch 80 Loss 0.1819
# Epoch 46 Batch 96 Loss 0.1812
# Epoch 46 Batch 112 Loss 0.1838
# Epoch 46 Batch 128 Loss 0.1896
# Epoch 46 Loss 0.1896
# Time taken for 1 epoch: 3.1081953048706055 secs
#
# Epoch 47 Batch 0 Loss 0.1496
# Epoch 47 Batch 16 Loss 0.1543
# Epoch 47 Batch 32 Loss 0.1642
# Epoch 47 Batch 48 Loss 0.1696
# Epoch 47 Batch 64 Loss 0.1769
# Epoch 47 Batch 80 Loss 0.1805
# Epoch 47 Batch 96 Loss 0.1844
# Epoch 47 Batch 112 Loss 0.1845
# Epoch 47 Batch 128 Loss 0.1909
# Epoch 47 Loss 0.1909
# Time taken for 1 epoch: 3.1007466316223145 secs
#
# Epoch 48 Batch 0 Loss 0.1909
# Epoch 48 Batch 16 Loss 0.1540
# Epoch 48 Batch 32 Loss 0.1529
# Epoch 48 Batch 48 Loss 0.1658
# Epoch 48 Batch 64 Loss 0.1629
# Epoch 48 Batch 80 Loss 0.1724
# Epoch 48 Batch 96 Loss 0.1730
# Epoch 48 Batch 112 Loss 0.1764
# Epoch 48 Batch 128 Loss 0.1836
# Epoch 48 Loss 0.1836
# Time taken for 1 epoch: 3.1168954372406006 secs
#
# Epoch 49 Batch 0 Loss 0.3056
# Epoch 49 Batch 16 Loss 0.1703
# Epoch 49 Batch 32 Loss 0.1468
# Epoch 49 Batch 48 Loss 0.1668
# Epoch 49 Batch 64 Loss 0.1715
# Epoch 49 Batch 80 Loss 0.1807
# Epoch 49 Batch 96 Loss 0.1835
# Epoch 49 Batch 112 Loss 0.1951
# Epoch 49 Batch 128 Loss 0.1966
# Epoch 49 Loss 0.1966
# Time taken for 1 epoch: 3.101271390914917 secs
#
# Epoch 50 Batch 0 Loss 0.0655
# Epoch 50 Batch 16 Loss 0.1406
# Epoch 50 Batch 32 Loss 0.1676
# Epoch 50 Batch 48 Loss 0.1697
# Epoch 50 Batch 64 Loss 0.1640
# Epoch 50 Batch 80 Loss 0.1668
# Epoch 50 Batch 96 Loss 0.1693
# Epoch 50 Batch 112 Loss 0.1721
# Epoch 50 Batch 128 Loss 0.1737
# Saving checkpoint for epoch 50 at checkpoints/ckpt-10
# Epoch 50 Loss 0.1737
# Time taken for 1 epoch: 3.4151482582092285 secs
#
# Epoch 51 Batch 0 Loss 0.2327
# Epoch 51 Batch 16 Loss 0.1324
# Epoch 51 Batch 32 Loss 0.1455
# Epoch 51 Batch 48 Loss 0.1409
# Epoch 51 Batch 64 Loss 0.1376
# Epoch 51 Batch 80 Loss 0.1387
# Epoch 51 Batch 96 Loss 0.1414
# Epoch 51 Batch 112 Loss 0.1457
# Epoch 51 Batch 128 Loss 0.1500
# Epoch 51 Loss 0.1500
# Time taken for 1 epoch: 3.1045756340026855 secs
#
# Epoch 52 Batch 0 Loss 0.0942
# Epoch 52 Batch 16 Loss 0.1217
# Epoch 52 Batch 32 Loss 0.1373
# Epoch 52 Batch 48 Loss 0.1287
# Epoch 52 Batch 64 Loss 0.1270
# Epoch 52 Batch 80 Loss 0.1310
# Epoch 52 Batch 96 Loss 0.1364
# Epoch 52 Batch 112 Loss 0.1465
# Epoch 52 Batch 128 Loss 0.1497
# Epoch 52 Loss 0.1497
# Time taken for 1 epoch: 3.091914176940918 secs
#
# Epoch 53 Batch 0 Loss 0.1434
# Epoch 53 Batch 16 Loss 0.1216
# Epoch 53 Batch 32 Loss 0.1191
# Epoch 53 Batch 48 Loss 0.1265
# Epoch 53 Batch 64 Loss 0.1315
# Epoch 53 Batch 80 Loss 0.1332
# Epoch 53 Batch 96 Loss 0.1347
# Epoch 53 Batch 112 Loss 0.1383
# Epoch 53 Batch 128 Loss 0.1407
# Epoch 53 Loss 0.1407
# Time taken for 1 epoch: 3.0955469608306885 secs
#
# Epoch 54 Batch 0 Loss 0.1125
# Epoch 54 Batch 16 Loss 0.1352
# Epoch 54 Batch 32 Loss 0.1195
# Epoch 54 Batch 48 Loss 0.1240
# Epoch 54 Batch 64 Loss 0.1294
# Epoch 54 Batch 80 Loss 0.1327
# Epoch 54 Batch 96 Loss 0.1321
# Epoch 54 Batch 112 Loss 0.1334
# Epoch 54 Batch 128 Loss 0.1357
# Epoch 54 Loss 0.1357
# Time taken for 1 epoch: 3.0936386585235596 secs
#
# Epoch 55 Batch 0 Loss 0.2248
# Epoch 55 Batch 16 Loss 0.1274
# Epoch 55 Batch 32 Loss 0.1056
# Epoch 55 Batch 48 Loss 0.1094
# Epoch 55 Batch 64 Loss 0.1195
# Epoch 55 Batch 80 Loss 0.1248
# Epoch 55 Batch 96 Loss 0.1272
# Epoch 55 Batch 112 Loss 0.1272
# Epoch 55 Batch 128 Loss 0.1283
# Saving checkpoint for epoch 55 at checkpoints/ckpt-11
# Epoch 55 Loss 0.1283
# Time taken for 1 epoch: 3.6042768955230713 secs
#
# Epoch 56 Batch 0 Loss 0.1176
# Epoch 56 Batch 16 Loss 0.1426
# Epoch 56 Batch 32 Loss 0.1330
# Epoch 56 Batch 48 Loss 0.1298
# Epoch 56 Batch 64 Loss 0.1321
# Epoch 56 Batch 80 Loss 0.1295
# Epoch 56 Batch 96 Loss 0.1301
# Epoch 56 Batch 112 Loss 0.1310
# Epoch 56 Batch 128 Loss 0.1331
# Epoch 56 Loss 0.1331
# Time taken for 1 epoch: 3.106982946395874 secs
#
# Epoch 57 Batch 0 Loss 0.0674
# Epoch 57 Batch 16 Loss 0.0975
# Epoch 57 Batch 32 Loss 0.1039
# Epoch 57 Batch 48 Loss 0.1166
# Epoch 57 Batch 64 Loss 0.1132
# Epoch 57 Batch 80 Loss 0.1160
# Epoch 57 Batch 96 Loss 0.1149
# Epoch 57 Batch 112 Loss 0.1189
# Epoch 57 Batch 128 Loss 0.1224
# Epoch 57 Loss 0.1224
# Time taken for 1 epoch: 3.0942647457122803 secs
#
# Epoch 58 Batch 0 Loss 0.1932
# Epoch 58 Batch 16 Loss 0.0864
# Epoch 58 Batch 32 Loss 0.1036
# Epoch 58 Batch 48 Loss 0.1220
# Epoch 58 Batch 64 Loss 0.1263
# Epoch 58 Batch 80 Loss 0.1276
# Epoch 58 Batch 96 Loss 0.1299
# Epoch 58 Batch 112 Loss 0.1332
# Epoch 58 Batch 128 Loss 0.1333
# Epoch 58 Loss 0.1333
# Time taken for 1 epoch: 3.1103973388671875 secs
#
# Epoch 59 Batch 0 Loss 0.1869
# Epoch 59 Batch 16 Loss 0.1131
# Epoch 59 Batch 32 Loss 0.1153
# Epoch 59 Batch 48 Loss 0.1096
# Epoch 59 Batch 64 Loss 0.1159
# Epoch 59 Batch 80 Loss 0.1266
# Epoch 59 Batch 96 Loss 0.1302
# Epoch 59 Batch 112 Loss 0.1279
# Epoch 59 Batch 128 Loss 0.1293
# Epoch 59 Loss 0.1293
# Time taken for 1 epoch: 3.1069719791412354 secs
#
# Epoch 60 Batch 0 Loss 0.0895
# Epoch 60 Batch 16 Loss 0.0846
# Epoch 60 Batch 32 Loss 0.0859
# Epoch 60 Batch 48 Loss 0.0901
# Epoch 60 Batch 64 Loss 0.0903
# Epoch 60 Batch 80 Loss 0.0901
# Epoch 60 Batch 96 Loss 0.0943
# Epoch 60 Batch 112 Loss 0.0980
# Epoch 60 Batch 128 Loss 0.0989
# Saving checkpoint for epoch 60 at checkpoints/ckpt-12
# Epoch 60 Loss 0.0989
# Time taken for 1 epoch: 3.408737897872925 secs
#
# Epoch 61 Batch 0 Loss 0.0410
# Epoch 61 Batch 16 Loss 0.0767
# Epoch 61 Batch 32 Loss 0.0836
# Epoch 61 Batch 48 Loss 0.0935
# Epoch 61 Batch 64 Loss 0.1019
# Epoch 61 Batch 80 Loss 0.1052
# Epoch 61 Batch 96 Loss 0.1060
# Epoch 61 Batch 112 Loss 0.1091
# Epoch 61 Batch 128 Loss 0.1182
# Epoch 61 Loss 0.1182
# Time taken for 1 epoch: 3.098989963531494 secs
#
# Epoch 62 Batch 0 Loss 0.0466
# Epoch 62 Batch 16 Loss 0.0940
# Epoch 62 Batch 32 Loss 0.1037
# Epoch 62 Batch 48 Loss 0.0938
# Epoch 62 Batch 64 Loss 0.0948
# Epoch 62 Batch 80 Loss 0.0962
# Epoch 62 Batch 96 Loss 0.0985
# Epoch 62 Batch 112 Loss 0.1008
# Epoch 62 Batch 128 Loss 0.1041
# Epoch 62 Loss 0.1041
# Time taken for 1 epoch: 3.0968234539031982 secs
#
# Epoch 63 Batch 0 Loss 0.2308
# Epoch 63 Batch 16 Loss 0.0862
# Epoch 63 Batch 32 Loss 0.0871
# Epoch 63 Batch 48 Loss 0.0933
# Epoch 63 Batch 64 Loss 0.1007
# Epoch 63 Batch 80 Loss 0.1001
# Epoch 63 Batch 96 Loss 0.1013
# Epoch 63 Batch 112 Loss 0.1047
# Epoch 63 Batch 128 Loss 0.1025
# Epoch 63 Loss 0.1025
# Time taken for 1 epoch: 3.1246538162231445 secs
#
# Epoch 64 Batch 0 Loss 0.0571
# Epoch 64 Batch 16 Loss 0.0728
# Epoch 64 Batch 32 Loss 0.0756
# Epoch 64 Batch 48 Loss 0.0749
# Epoch 64 Batch 64 Loss 0.0819
# Epoch 64 Batch 80 Loss 0.0826
# Epoch 64 Batch 96 Loss 0.0829
# Epoch 64 Batch 112 Loss 0.0827
# Epoch 64 Batch 128 Loss 0.0811
# Epoch 64 Loss 0.0811
# Time taken for 1 epoch: 3.119659423828125 secs
#
# Epoch 65 Batch 0 Loss 0.0807
# Epoch 65 Batch 16 Loss 0.0415
# Epoch 65 Batch 32 Loss 0.0743
# Epoch 65 Batch 48 Loss 0.0815
# Epoch 65 Batch 64 Loss 0.0843
# Epoch 65 Batch 80 Loss 0.0833
# Epoch 65 Batch 96 Loss 0.0835
# Epoch 65 Batch 112 Loss 0.0857
# Epoch 65 Batch 128 Loss 0.0897
# Saving checkpoint for epoch 65 at checkpoints/ckpt-13
# Epoch 65 Loss 0.0897
# Time taken for 1 epoch: 3.4864342212677 secs
#
# Epoch 66 Batch 0 Loss 0.1652
# Epoch 66 Batch 16 Loss 0.0968
# Epoch 66 Batch 32 Loss 0.0935
# Epoch 66 Batch 48 Loss 0.0891
# Epoch 66 Batch 64 Loss 0.0950
# Epoch 66 Batch 80 Loss 0.0981
# Epoch 66 Batch 96 Loss 0.1007
# Epoch 66 Batch 112 Loss 0.0989
# Epoch 66 Batch 128 Loss 0.0963
# Epoch 66 Loss 0.0963
# Time taken for 1 epoch: 3.1179842948913574 secs
#
# Epoch 67 Batch 0 Loss 0.0081
# Epoch 67 Batch 16 Loss 0.0513
# Epoch 67 Batch 32 Loss 0.0627
# Epoch 67 Batch 48 Loss 0.0667
# Epoch 67 Batch 64 Loss 0.0780
# Epoch 67 Batch 80 Loss 0.0825
# Epoch 67 Batch 96 Loss 0.0847
# Epoch 67 Batch 112 Loss 0.0901
# Epoch 67 Batch 128 Loss 0.0937
# Epoch 67 Loss 0.0937
# Time taken for 1 epoch: 3.1000847816467285 secs
#
# Epoch 68 Batch 0 Loss 0.0306
# Epoch 68 Batch 16 Loss 0.0861
# Epoch 68 Batch 32 Loss 0.0857
# Epoch 68 Batch 48 Loss 0.0843
# Epoch 68 Batch 64 Loss 0.0816
# Epoch 68 Batch 80 Loss 0.0847
# Epoch 68 Batch 96 Loss 0.0852
# Epoch 68 Batch 112 Loss 0.0859
# Epoch 68 Batch 128 Loss 0.0887
# Epoch 68 Loss 0.0887
# Time taken for 1 epoch: 3.0985381603240967 secs
#
# Epoch 69 Batch 0 Loss 0.0894
# Epoch 69 Batch 16 Loss 0.0646
# Epoch 69 Batch 32 Loss 0.0598
# Epoch 69 Batch 48 Loss 0.0598
# Epoch 69 Batch 64 Loss 0.0630
# Epoch 69 Batch 80 Loss 0.0727
# Epoch 69 Batch 96 Loss 0.0805
# Epoch 69 Batch 112 Loss 0.0847
# Epoch 69 Batch 128 Loss 0.0866
# Epoch 69 Loss 0.0866
# Time taken for 1 epoch: 3.0935819149017334 secs
#
# Epoch 70 Batch 0 Loss 0.0300
# Epoch 70 Batch 16 Loss 0.0349
# Epoch 70 Batch 32 Loss 0.0523
# Epoch 70 Batch 48 Loss 0.0718
# Epoch 70 Batch 64 Loss 0.0738
# Epoch 70 Batch 80 Loss 0.0784
# Epoch 70 Batch 96 Loss 0.0802
# Epoch 70 Batch 112 Loss 0.0816
# Epoch 70 Batch 128 Loss 0.0842
# Saving checkpoint for epoch 70 at checkpoints/ckpt-14
# Epoch 70 Loss 0.0842
# Time taken for 1 epoch: 3.4057042598724365 secs

# %%
def evaluate(input_document):
    input_document = document_tokenizer.texts_to_sequences([input_document])
    input_document = tf.keras.preprocessing.sequence.pad_sequences(input_document, maxlen=encoder_maxlen, padding='post', truncating='post')

    encoder_input = tf.expand_dims(input_document[0], 0)

    decoder_input = [summary_tokenizer.word_index["<go>"]]
    output = tf.expand_dims(decoder_input, 0)
    
    for i in range(decoder_maxlen):
        enc_padding_mask, combined_mask, dec_padding_mask = create_masks(encoder_input, output)

        predictions, attention_weights = transformer(
            encoder_input, 
            output,
            False,
            enc_padding_mask,
            combined_mask,
            dec_padding_mask
        )

        predictions = predictions[: ,-1:, :]
        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        if predicted_id == summary_tokenizer.word_index["<stop>"]:
            return tf.squeeze(output, axis=0), attention_weights

        output = tf.concat([output, predicted_id], axis=-1)

    return tf.squeeze(output, axis=0), attention_weights

# %%
def summarize(input_document):
    summarized = evaluate(input_document=input_document)[0].numpy()
    summarized = np.expand_dims(summarized[1:], 0)  # not printing <go> token
    return summary_tokenizer.sequences_to_texts(summarized)[0]  # since there is just one translated document

# %%
output = []
for i in tqdm.tqdm(df.Text):
    output.append(summarize(i))
# Out:
# 100%|██████████| 1026/1026 [17:50<00:00,  1.04s/it]

# %%
reference = []
for i in tqdm.tqdm(df.Summary):
    reference.append(i)
# Out:
# 100%|██████████| 1026/1026 [00:00<00:00, 1139056.62it/s]

# %%
reference
# Out:
# ['বাংলাদেশে কোচিং বানিজ্য বন্ধ এখন সময়ের দাবি',
#  'বাংলা ভাষার প্রযুক্তি নিয়ে আমাদের আরো অনেক বেশি আগ্রহী ও গবেষণায় মনোযোগ দিতে হবে',
#  'যদি শিশুরা বই পড়ার অভ্যাস করে তাহলে সারা জীবনের জন্য আমরা তাদের নিয়ে নিশ্চিন্ত থাকতে পারব।',
#  'বাংলাদেশে সব স্তরে নারীর ক্ষমতায়নের জন্য আরও অনেক কাজ করে যেতে হবে।',
#  'ভালো কথা বল, নয়ত চুপ থাকো',
#  'সমাবর্তনের মাধ্যমে শিক্ষা জীবনের শেষ হলেও সফলতা ও ব্যর্থজীবনের হিসাব গণনা শুরু হয়ে এখান থেকেই',
#  'বাবার কষ্টার্জিত অর্থের মূল্য দিতে শিখো',
#  'নিজের ভুলের জন্য অনুতপ্ত হওয়া উচিত',
#  'দুশমনের শরণ ক্ষতির কারণ',
#  'অনেক গুলো গুনোবানহীন সন্তানের চেয়ে একটি গুনবান পূর্ন সন্তানই যথেষ্ট',
#  'মানুষ যখন বিপদে পরে তখন সমাজের তুচ্ছ মানুষরাও তাকে অপদস্ত করে',
#  'কারো পৌষ মাস,আবার কারো সর্বনাশ',
#  'আমাদের সমাজেও এমন অনেক লোক আছে যারা মুখে বলে এক কথা কিন্তু করে আরেক',
#  'উপকারীর উপকার স্বীকার করতে হবে ',
#  'দিনশেষে এই পৃথিবীর বেশিরভাগ মানুষ কেউ কাউকে বুঝে না',
#  'যেদিন মিথ্যেগুলোকে সত্যি সত্যি মিথ্যে মনে হবে, সেদিন সব শেষ হয়ে যাবে',
#  'একটা মানুষ যখন বিশ্বাস করতে শুরু করে যে সে আমার সাথে ভালো থাকবে না, ঠিক তখনই সে চলে যায়',
#  'কষ্ট দুর্বোধ্য না, কষ্ট থেকে বের হবার উপায় দুর্বোধ্য',
#  'ভালো থাকতে হলে আগে চাওয়া-পাওয়ার হিসেব মেলাতে হয়',
#  'এই পৃথিবীতে যারা এখনো কষ্ট পেলে মন উজাড় করে কাঁদতে পারে, তারাই ভালো আছে',
#  'ধর্ষণের শাস্তি হতে হবে কঠোর',
#  'দিনশেষে নিজের ভালবাসার মানুষকে জীবনে সবচেয়ে বেশি প্রয়োজন',
#  'জীবনটা একটা যুদ্ধ পরিশ্রম ছাড়া এই যুদ্ধে জেতা যায় না',
#  'সমায়ের সাথে সব কিছুর পরিবর্তন হয়',
#  'যুদ্ধ জয়ের হাঁসি হাসে মানুষ সমাবর্তনে',
#  'দিনশেষে মানুষ সব পারে',
#  'জীবনটা কারো জন্য থেমে থাকে না',
#  'রাস্তায় চলাচলে আমাদের অনেক বেশি সাবধানতা অবলম্বন করতে হবে',
#  "আমাদের জীবনের অনেক সিদ্ধান্ত এইসব 'হয়তো', 'যদি', 'কিন্তু' তে আটকে থাকে",
#  'গর্বের সাথে বাবা-মায়ের পরিচয় দিতে সমাজের মানুষের তথাকথিত স্বীকৃতির কোন প্রয়োজন নেই',
#  'সবকিছুর সাথে আপোষ করা যায়,কিন্তু নিজের আত্মসম্মানকে যে আঘাত করে,তার সাথে আপোষ করার প্রশ্নই আসেনা ',
#  'সত্যিকারের ভালোবাসা জীবন থেকে হারাতে দেয়া যাবে না',
#  'মানুুষ দিনকে দিন হিংস্র হয়ে উঠছে',
#  'দিনশেষে চুপচাপ বসে থাকাটা একটা ক্ষণস্থায়ী সমাধান আর দীর্ঘস্থায়ী সমস্যার জন্ম দেয়',
#  'জীবনের একেকটা পর্যায়ে নিজের একেকটা অংশকে ফেলে রেখে আসার নামই বোধহয় বদলে যাওয়া',
#  'মন থেকে যে মানুষটাকে ভালোবাসি, তার অবহেলাকে পাল্টা অবহেলা করা যায় না',
#  'বিদেশ থেকে উচ্চশিক্ষা গ্রহন এর পর শিক্ষার্থীদের নিজ দেশের সেবায় দেশে ফিরা উচিত',
#  'সত্যিকারের বিশ্ববিদ্যালয় হতে হলে তাকে জ্ঞান সৃষ্টি করতে হয়',
#  'নূতন পৃথিবীটিতে জ্ঞান হচ্ছে সম্পদ এবং সেই সম্পদের পরিমাপ করা হয় পেটেন্ট দিয়ে',
#  'শিক্ষকতার মত মহৎ পেশা নিয়ে আমরা এই যুগেও নাক ছিটকাই',
#  'বোকা মানুষগুলো আশায় বাঁচে আর হতাশায় ধুকে ধুকে মরতে থাকে',
#  'নিজেকে ব্যখ্যা করাটা সত্যিই অনেক কঠিন',
#  'পারফেক্ট লাইফ বলে মনে হয় কিছুই নেই',
#  'মন খারাপের গল্প বলার শেষ মানুষটাও চলে গেলে তা সয়ে নেয়া ভীষণ ভীষণ কঠিন',
#  'আল্লাহ্\u200cর কাছে আমাদের মন খুলে চাইতে হবে',
#  'বড় হয়ে যাওয়ার সমস্যাটা এখানেই ,চাইলেই চিৎকার করে কাঁদা যায় না',
#  'দুনিয়াতে সবাই নিজের পাপের ফল পাবে',
#  'পৃথিবীর সব কিছু আমরা ঠিক যেমন করে চাই তেমন করে হবে না',
#  'এই ব্যাস্ত শহরে কেউ কারো না,সবাই নিজেকে নিয়ে ব্যাস্ত',
#  'জীবনে মায়ের গুরুত্ব কোনো কিছুর সাথে তুলনা করে বুঝানো যাবে না',
#  'আজম খানের বীরত্ব গাঁথা',
#  'ভারতে হিন্দু মুসলিম দাঙ্গা',
#  'ঢাকা শাহজালাল বিমানবন্দরে নেমে ফ্রি তে কল করতে পারবে যাত্রীরা',
#  'অন্যের জন্য নিজের ক্ষতি করা যবে না',
#  'ডাক্তার রোগীর দুঃখ তখনই বুঝবে যদি ডাক্তারের ও সেইম রোগ হয়ে থাকে',
#  'পাগল হউক আর যেই হউক সবার জীবনের মূল্য আছে',
#  'জীবন কারো জন্য থেমে থকে না',
#  'যত দিন মেয়েরা পুরুষের চরিত্র বলতে কেবলই প্রজননযন্ত্রের একমুখিতাকে বুঝবে,তত দিন দেশ দুর্নীতিমুক্ত হবে না',
#  'মেয়েদের মতো জটিল ঘরোয়া বুদ্ধি পুরুষদের মাথায় তেমন ঢোকে না',
#  'পুরুষের অব্যক্ত বেদনার কথা হয়তো কেউ কখনও বলবে না',
#  'পুরুষদের যে নিরাপত্তার অভাব, এটা মেনে নিতে পর্যন্ত এ সমাজ কুণ্ঠিত হয়',
#  'পুরুষ মানুষ সমাজে প্রতিনিয়ত অবহ্লিত হয়ে আসছে',
#  'দেখেশুনে, হিসেব কষে প্রেম হয় না, বড়জোর ব্যবসা হয়',
#  'সময়ের কাজ সময়ে করতে হবে',
#  'ভালোবাসায় শান্তি আছে, শক্তি আছে, স্বস্তি আছে',
#  'বাবাা মার দোয়া ছাড়া জীবনে সামনে আগানো কঠিন',
#  'একজন মানুষের সবচাইতে বড় গুণটি হল মানবিকতা',
#  'যার সার্টিফিকেট যত ভারী, তার অর্থসংক্রান্ত ঘিলু তত কম',
#  'সব সম্পর্কে যেমনি ভালোবাসা থাকে না, ঠিক তেমনি সব ভালোবাসায় সম্পর্ক থাকে না',
#  'ভালোবাসাকে সব সময়ই যে একটা টু-ওয়ে ট্রাফিক হতে হবে, এমন নয়',
#  'সত্যি না জেনে মানুষ অনেক সময় একে অপরকে ভুল বুঝে',
#  ' কাছের কারও কাছে নিজেকে বোঝাতে না পারার মতো অসহায়ত্ব আর নেই',
#  'কাউকে কষ্ট দিতে হয় না, প্রকৃতি তা বহুগুণে ফেরত দেয়',
#  'আপনি যদি আপনার মতো করে শতভাগ আনুগত্য চান, তবে একটা কুত্তা পালেন, মানুষ না।',
#  'সবার একটা ব্যক্তিগত জীবন থাকে',
#  'বড় মানুষগুলো কাছ থেকে সাধারণত বড় নন',
#  'যার বিশ্বাস যত বড়, তার গন্তব্য তত বড়',
#  'যে শূন্যে যেতে পারে না, সে কখনও দশেই উঠতে পারে না',
#  'মানুষের মেধার মূল্যায়ন করত',
#  'ভালোবাসার মানুষ এর সামনেই নিজের সুস্থতা',
#  'নিজেরা নিজেদের ক্ষতি করিস না',
#  'কারো সম্পর্কে ভালো বলতে না পারলেও খারাপ বলা উচিত না',
#  'যুদ্ধে আহত শত্রুর প্রতি মানবতা দেখানো উচিত ',
#  'সোভিয়েত ইউনিয়ন এর  ঘুম নিয়ে এক অদ্ভুত এক্সপেরিমেন্ট',
#  'স্বামী-স্ত্রীর সম্পর্ক মানে একে অপরের দোষ ঢেকে রাখার একটা সম্পর্ক',
#  'জীবনে চলার পথে নতুন কিছু গড়তে পুরনো কে ভাঙ্গতে হবে',
#  'একটা সম্পর্কে দুই জনকেই আন্তরিক হতে হবে',
#  'ভালোবাসা সে যে পৃথিবীর শ্রেষ্ঠ অনুভূতি',
#  'বাবা  মার ঝগড়া কখনো যেনো সন্তানের উপর বিরূপ প্রভাব না ফেলে সেদিকে খেয়াল রাখতে হবে',
#  'অন্যের দোহাই দিয়ে আমরা অনেক সময় নিজেদের স্মাজের কটু কথা থেকে বাঁচতে অনেক পদক্ষেপ নেই',
#  'অপেক্ষাই হলো শুদ্ধতম ভালোবাসা ও ভালোথাকা',
#  'কাউকে কোনও সেবা দেওয়ার জন্য টাকা নেওয়ার সময় এমন একটাও কমিটমেন্ট করবেন না, যা রাখা আপনার পক্ষে সম্ভব নয়',
#  'ব্যবসার নামে ব্যাবসা করা মানুষ গুলা সমাজের কীট',
#  'এ দুর্ভাগা দেশে আপনি টাকা দিয়েও প্রাপ্য সেবাটি পাবেন না',
#  'জীবন হলো নদীর মতো , প্রবাহ মান',
#  'ছেলেদের জীবনে অনেক কষ্ট করতে হয়। ',
#  'ভালোবাসা আসীম',
#  'ভাালোবাসার মানুষ এর মাঝে কেও পুরো পৃথিবী খুজে পায়',
#  'মানুষ এর বই মেলাতে যাওয়ার গুরুত্ব অপরিসীম ',
#  'বাংলা সাহিত্য সম্পর্কে জানতে হলে মানিক বন্দ্যোপাধ্যায়, সৈয়দ ওয়ালীউল্লাহ, আজিজুল হক , শহীদুল জহির, সৈয়দ শামসুল হক এর সাহিত্য পড়া অতিব জরুরী',
#  'সাম্প্রদায়িক সম্প্রীতি সমুন্নত রাখুন',
#  'বিনম্রতা একটি মহৎ গুন',
#  'মাঝে মাঝে বুদ্ধির অহংকারে চালাকি করতে গিয়ে ভাগ্য এমন বিড়ম্বনা ঘটায় যা মানুষ স্বপ্নেও ভাবতে পারে না ।',
#  'মানুষ অনেক সময় না বুঝে এমন জিনিস চায় , যা পেতে না পেতে তার থেকে মুক্তি পাবার জন্য ব্যতিব্যস্ত হয় পড়ে ।',
#  'কাজের সময় এবং খেলার জন্য একটি সময় আছে।',
#  'অহংকার ও দুর্বিনীতি আচরন সহজেই প্রতিপক্ষ দৃষ্টি আকর্ষণ করে ।',
#  'পরিস্থিতি ভেবে কাউকে সাহায্য করা উচিত ।',
#  'দুর্বল সবলের চাল চালতে গেলে তার নিজেরই সর্বনাশ হয় ।',
#  'সবসময় উপকারের বদলে প্রত্যুপকার করতে হয় ।',
#  'অন্যায়ের বিরুদ্ধে প্রথমবারই যদি রুখে দাঁড়ানো যায় , তা হলে পরবর্তীতে তোমার প্রতি অন্যায় করতে কেউ সাহস পাবে না ।',
#  'মানুষের মাঝে স্বার্থ ভিত্তিক বিভাজন সৃষ্টি হলে, তারা অন্যায় কাজ প্রতিরোধ করার সামর্থ্য হারিয়ে ফেলবে।',
#  'অনেক ক্ষেত্রেই কাগুজে ডিগ্রির চেয়ে অভিজ্ঞতা মূল্য বেশী।',
#  'যে যত উপরে, তাঁর চুরি ততো বড় এবং তা ধরা ছোঁয়ার বাইরে।',
#  'চোরের উপর বড় চোর আছে ',
#  'কারো ক্ষতি করা খারাপ',
#  'ধর্য একটি মহৎ গুন',
#  'সময়ের গুরুত্ব দিতে হবে',
#  'কেউ কোনো প্রশ্ন করলে তাকে পাল্টা কোনো প্রশ্ন না করার মাঝে এক প্রকার পৈশাচিক আনন্দ আছে',
#  'সমাজে প্রকৃত মানুষের বড়ই অভাব',
#  'জীবনে যত বড়ই কষ্ট পাই না কেনো কখনো নিজের ক্ষতি করা যাবে না',
#  'স্বাধীনতার জন্য মুক্তির জন্য জীবন দিয়ে দেয়া',
#  'পুরোনো ভালোবাসার স্মৃতিচারণ',
#  'উপন্যাস লেখার বেপারে অনুপ্রেরণা',
#  'জীবনে  হাজার কষ্টের মাঝেও নিজেকে সুখী রাখতে হবে',
#  'আপনি যদি ব্যর্থ হন, আপনার দ্বারা শিল্প হবে',
#  'ই একজন পুরস্কার-বিজয়ীর জীবন চিরদিনের জন্য আলোর দিকে ভালোর দিকে পাল্টে দিতে পারে',
#  'সফলতা হচ্ছে একটি আপেক্ষিক ব্যাপার',
#  'আমি হাসিমুখে ভোট চাইতে লাগলাম। ',
#  'আমি আপনাকে এখনও ভালবাসি।',
#  'মেয়েদের সম্মান করার মধ্যে দিয়ে মাকে সম্মান করা হয়  কারণ সে একসময় মা হবে। ',
#  'দায়িত্ব নেওয়ার ভয়ে স্বামীর সংসার ত্যাগ করা এবং কোনো ধরনের সম্পর্কে না জড়ানো।',
#  'মিথ্যা সম্পর্ক রাখার চেয়ে  না রাখা অনেক ভালো।',
#  'অতি চালকের গলায় দড়ি ',
#  'কালো কলঙ্কের দাগ হলেও মাঝে মধ্যে কালোকে বাদে সাদাকে অসম্পূর্ণ লাগে.',
#  'কেও আমাদের  প্রতি সম্মান ও ভালোবাসা দেখালে , আমাদেরও উচিত তাদের প্রতি সম্মান ও ভালোবাসা দেখানো। ',
#  'বই পড়া এবং উপহার দেওয়ার মাঝে সুখ খুঁজে নেই ।',
#  'ভাগ্য আগেই নির্ধারণ থাকে তার মানে এই না যে আপনি চেষ্টা করবেন না, আমাদের উচিত চেষ্টা করা এবং আল্লাহর উপর ভরসা রাখা। ',
#  'একাকিত্ব জীবন অনেক বেদনাময়। ',
#  'পৃথিবীতে কোনো কাজকেই  ছোট করে দেখা উচিত নয়. সেই কাজের প্রতি মনে সন্তুষ্টি থাকাটাই জরুরী। ',
#  'পৃথিবীতে কোনও মেয়েই নিখুঁত নয়  তবে এমন একজন মেয়ে থাকবে যে আপনার জন্য নিখুঁত.',
#  'খ্যাতির বিড়ম্বনা ',
#  'একটি বই নাম তার অদম্য সিসিফাস। ',
#  'অল্পতেই সুখ খুঁজে নিতে হয়। ',
#  'কৃতজ্ঞ থাকুন যা আপনি পেয়েছেন। ',
#  'মানুষের ভুল গুলো গ্রহণ করতে শেখা। ',
#  'সত্যিকারের ভালোবাসা  খুব বেশী সাধারণ হয়। ',
#  '"সম্পর্কগুলোকে সময় থাকতে মূল্য খুব দরকার।  তাজমহল দেখা তো সবার ভাগ্যেই জুটেছে শুধু মমতাজ বাদে।"',
#  'মানুষের থাকা আর না থাকাটা স্মৃতি হয়ে যায়। ',
#  'ইহুদিদের উপর ঘৃণা',
#  'জীবনের প্রতি ক্লান্ততা.',
#  'তারকাদের জীবনের গল্প।',
#  'নতুন বছর আর নতুন নতুন সম্পর্ক .',
#  'এয়ারপোর্ট  এ  চলাচলরত মানুষের জীবন কাহিনী।',
#  'নিজের জীবনের জন্য জীবনসঙ্গী খুঁজা।',
#  'নিজের নিরাপত্তা নিশ্চিত করার দায়িত্ব নিজেকেই নিতে হবে',
#  'চেষ্টা করলে সফলতা আসবে',
#  'সব জায়গাতে সব নিয়ম চলে না।',
#  'একটি মানুষকে জানার প্রতি আগ্রহ। ',
#  'শখের জন্য কি না করতে হয়।',
#  'ওয়াজেদ আলীর জীবনী',
#  'স্ত্রী স্বামীকে বোকা বানিয়েছে।',
#  ' মানুষ বিভিন্ন ধরনের।',
#  'বই পড়ুন, বই উপহার দিন এবং দুটো লাইন লিখে দিন।',
#  ' ভালোবাসার মানুষ পেলে তাকে আকড়ে ধরে রাখতে হয়।',
#  'অল্পতেই সুখ খুঁজে নেয়া।',
#  'একটি মেয়ের কাহিনী।',
#  'ভালো ছিল সেই সোনালি অতীতটা।',
#  'ভালোবাসতে একজন  অন্যজনকে বুঝতে হবে। ',
#  'জেদ মানুষ কে বড় করতে পারে না .',
#  'নিজের ব্যর্থতা  কারো উপর চাপিয়ে দেয়া যাবে না',
#  'করোনা ভাইরাস আক্রমণ বাংলাদেশের প্রেক্ষিতে।',
#  'আগের সময়ের কিছু স্মৃতি।',
#  'একটি নারীর যুদ্ধে রুখে দাঁড়ানোর গল্প নারীদিবসে সম্মান  এনে দেয়। ',
#  'মায়ের মর্ম বোঝানো হয়েছে।',
#  'রিভিশন দেওয়ার কৌশল।',
#  'প্রেগন্যান্সিতে ডাক্তারের সাজেশন । ',
#  'প্রেম দ্বিতীয় সুযোগের দাবি রাখে।',
#  'ইট মারলে পাটকেলটি খেতে হয়। ',
#  'আমাদের দেশে শিক্ষা ব্যবস্থা পরিবর্তন করা উচিত। ',
#  'আঞ্চলিক ভাষার মাঝেই আছে আত্মপরিচয়।',
#  'চাঁদপুর যাওয়ার অভিজ্ঞতা। ',
#  'নিজে কিছু  লিখার আগে অন্যের লিখা পড়ার ধোর্য রাখতে হয়। ',
#  'ভালোবাসার মানুষের জন্য  আত্মসম্মান কম্প্রোমাইজ করা উচিত নয়।',
#  'বাংলা ভাষার  প্রতি সম্মান জানানো উচিত।',
#  'অবহেলা পেতে পেতে পরে তা আর গায়ে লাগে না।',
#  'যে আত্মহত্যা করে তার। মনের কষ্ট কেউ বোঝে না।',
#  'জীবনে নতুন নতুন মানুষ আসলে পুরাতন মানুষ হারায়ে যায়।',
#  'অন্যকে বলার আগে নিজেকে ঠিক হতে হবে। ',
#  'দাম দিলে মান রাখতে হয়। ',
#  'নিজের ব্যক্তিত্বকে সম্মান করতে শিখা।',
#  'রাগের প্রকাশ করতে ইচ্ছে হয় মাঝেমাঝে। ',
#  ' মানুষ তার উপরই রাগ করতে পছন্দ করে যাকে সে ভালোবাসে ',
#  'অতিরিক্ত লজ্জা মানুষের জীবন কে নষ্ট করে দেয়ার জন্য যথেষ্ট। ',
#  'ভালোবাসার মানুষের মায়ায় পরা উচিত।\n',
#  'আপোনজনরাই জীবনের সব। ',
#  ' কাউকে ভালোবাসলে তার সবকিছুকেই ভালোবাসতে হয়।',
#  'ধর্ষকের চেয়ে একজন বেশ্যা হাজারগুনে ভালো।',
#  'কষ্ট করে পাওয়া জিনিসের মূল্য অনেক। ',
#  'বাংলায় কিছু বললে তার মূল্যটা অনেক বেশি। ',
#  'না চাইতেও বিচ্ছেদ। ',
#  'বিচ্ছেদে কষ্ট না পেয়ে আগামী দিনের জন্য অপেক্ষা করো। ',
#  'মিথ্যা ভালোবাসা। ',
#  'কেউ না কেউ আপনাকে অনেক ভালোবাসে। ',
#  'ভালোবাসা মানে তার শরীর কে ভালোবাসা না তার মন কে ভালোবাসা।',
#  'মহিলাদের চেয়ে পুরুষেরা অনেক সোজা প্রকৃতির হয়',
#  'ফ্রেন্ডের বিভিন্ন ধরণ.',
#  'কষ্ট মানুষকে আরো শক্তিশালী করে তুলে। ',
#  'ব্যস্ততার মাঝে তোমাকেও ভুলে যাবো একদিন। ',
#  'কাছের মানুষ থেকে পাওয়া কষ্ট খুব কঠিন। ',
#  'বঙ্গবন্ধুর প্রতি আমরা কৃতজ্ঞ।',
#  'চরিত্রহীন বড়লোক ছেলের চেয়ে চরিত্রবান মধ্যবিত্ত ছেলে ভালো।',
#  'স্বামী স্ত্রীর একে অপরকে সহযোগিতা করা উচিত। ',
#  'আত্মসম্মান নিয়ে বাঁচতে শেখা উচিত।',
#  'অন্যের সাথে কথা হচ্ছে। ',
#  'ভালোবাসার নামে পেইন দেয়া উচিত না। ',
#  'প্রেম না তার মায়ায় পড়েছি। ',
#  ' খোলা চুলে তাকাতো সে। ',
#  'কখন কার প্রতি ভালোবাসা আসে তা কেউ বলতে পারে না। ',
#  'প্রেমে জোর না থাকলে তা একদিন শেষ হয়ে যাবে। ',
#  'মনের মানুষ একটাই হয়। ',
#  'নামাজ পড়লেই হয় না , ঈমান থাকাটা দরকার। ',
#  'কিছু না বলা কখনও কখনও সর্বাধিক বলে।',
#  'নিজের দোষ অন্যের উপর চাপিয়ে দেয়া।',
#  'যে যত যে জিনিসে হোঁচট খেয়েছি সে ততো জিনিসটার মর্ম বোঝে।',
#  'ভালোবাসাতে মানুষের জন্য  মনের  টান থাকা দরকার।',
#  ' কাউকে  পাওয়ার  অতি  আগ্রহ ',
#  'আকাশ  পাতাল  পার্থক্য ',
#  'মনের ইচ্ছা পূরণ  না  করার  বেদনা ',
#  'ভালোবাসায় দেয়া সেরা উপহার হচ্ছে সময় আর শ্রদ্ধা।',
#  ' নিজের কাছে নিজে আগে ভালো হতে পারাটা গুরুত্বপূর্ণ।',
#  'সময় পরিবর্তনশীল।',
#  ' কথার ধরন বোঝা কঠিন।',
#  'জোর করে ভালোবাসা পাওয়া যায় না।',
#  'বৃদ্ধ বয়সে কাউকে পাশে চাওয়ার ইচ্ছা।',
#  ' চাকরি পেয়ে সংসার করার তীব্র ইচ্ছা',
#  ' বিপরীত আকর্ষণ। ',
#  'প্রেমে ছেকা',
#  'নিজের উপর আত্মবিশ্বাস রাখতে হবে। ',
#  'খারাপ অবস্থা মানুষের জীবন থেকে অনেক মূল্যবান জিনিস ও নিয়ে যায়.',
#  'লক্ষ্য স্থির থাকলে সেটা আপনি পাবেনই। ',
#  'প্রতারক, ভন্ড ও চরিত্রহীনদের মুখে মধু অন্তরে বিষ থাকে.',
#  'বেঁচে থেকেও যে নেই , তা মেনে নেয়া অনেক কঠিন। ',
#  'সৃষ্টিকর্তার উপর ভরসা রাখতে হবে , মানুষের উপর না। ',
#  'প্রেমিকার দায়িত্ব কি হওয়া উচিত?',
#  'একসাথে থাকতে চেয়েও এক না হতে পারার কষ্ট অনেক।',
#  'অতিরিক্ত ভালোবাসতে পারা মানুষজন অনেক  শক্ত হয়। ',
#  ' যে তোমার কষ্টের মূল্য দিবে তাকে আগলে রাখা উচিত। ',
#  'নিজে আয় করার তৃপ্তি অনেক। ',
#  'যে চলে গেছে তাকে যেতে দেয়। ',
#  'যে কষ্ট পাই সেই শুধু কষ্টের মৰ্ম বুঝে। ',
#  'মিথ্যা অভিনয়। ',
#  'বাংলা  হওয়া উচিত আমাদের অভিজাত ভাষা , বাংলা ইংরেজি মিলে নয়। ',
#  'নিজের উপর আত্মবিশ্বাস রাখতে হবে। ',
#  'খোঁচাখুঁচির সম্পর্কগুলো অনেক মিষ্টি হয়। ',
#  'কারো অনুপস্থিতিতেও কাউকে ভালোবাসা যায়।',
#  'কষ্টের ও সীমা আছে। ',
#  ' মানুষ সব সময় একরকম থাকে না। ',
#  'নিজের উপর বিশ্বাস রাখতে হবে। ',
#  'ভাষার প্রতি শ্রদ্ধা। ',
#  'গুরুত্ব থাকলে দূরত্বটাও কমে যায়। ',
#  'মানুষ ভালো জিনিসের অপেক্ষায় থাকে। ',
#  'কিছু মানুষকে চাওয়া আর না চাওয়া একই কথা। ',
#  'নিজেকে ভালো রাখার জন্য নিজের কষ্ট গুলো গোপন করে রাখাটাই শ্রেয়।',
#  'বন্ধু অনেক ধরণের হয়। ',
#  'বলা আর করা এক নয়। ',
#  'ভালো থাকার অভিনয় করা মানুষগুলোর উপর মায়া লাগে। ',
#  'অনেক খারাপ মানুষের ভীড়েও একজন  ভালো মানুষ থাকে। ',
#  'নরম মানুষের উপর সবাই ঝাঁপিয়ে পরে। ',
#  ' গায়ের রং দেখে কাউকে বিচার করা উচিত না। ',
#  ' মানুষকে চিনতে শিখুন। ',
#  ' সুযোগ পেলে অপমান করা মানুষ কখনো বন্ধু হতে পারে না। ',
#  ' সবচেয়ে বেশি অভিনয় আমরা নিজের সাথে করি। ',
#  ' আসল মানুষকে চেনা দরকার। ',
#  ' সবার একটি হিংসুটে প্রেমিক থাকা দরকার। ',
#  ' আবেগকে কমিয়ে ফেলা উচিত। ',
#  ' নিজের কষ্ট কাউকে অনেক সময় বলতে ইচ্ছে করে না। ',
#  ' জীবনসঙ্গীর কষ্টটাকে মেনে নিতে হবে। ',
#  ' কিছু চাওয়া পাওয়াবিহীন সম্পর্ক থাকে। ',
#  '  সময়ের সাথে অসংখ্য ভার্চুয়াল সম্পর্ক হারিয়ে যায়',
#  'নিজেই নিজের জীবনকে বদলাতে পারেন।',
#  'স্যাপিওস্যাক্সুয়াল মানুষগুলো বুদ্ধিদীপ্ত হয়।',
#  ' যোগ্যতা দিয়ে ভালোবাসা হয়না।',
#  'সৃষ্টির সৌন্দর্যই প্রকৃত সৌন্দর্য।',
#  'ভালোবাসার মানুষের চাওয়া পাওয়ার মূল্য দেয়া। ',
#  'সবার কাছে ভালো থাকার প্রয়োজন নেই। ',
#  'থেকেও না থাকার কষ্ট অনেক বেশি। ',
#  'মনের \u200cকথা বলতে না পারায় অনেক মানুষ জীবন থেকে চলে যায়।',
#  'স্কুল লাইফের বন্ধু আসল বন্ধু।',
#  'একা বেঁচে থাকা শিখা উচিত। ',
#  'যে চলে যাওয়ার সে চলে যাবেই।',
#  'অনেক সময় কষ্টের কথা বলা যায় না। ',
#  'নিজের ইচ্ছা শক্তিই আসল।',
#  'একটি মানুষের ভিতরে দুই রকমের স্বভাব থাকতে পারে। ',
#  'অন্যকে কষ্ট দেয়ার চেয়ে নিজে  কষ্টে থাকা ভালো। ',
#  'নারীরা যেমন ভালোবাসতে জানে তেমনি ঘৃণা করতেও জানে।   ',
#  'ভালোবাসার জন্য একটি  মানুষই যথেষ্ট। ',
#  'ভালোবাসা হওয়া উচিত মহান। ',
#  'হাসি খুশি থাকার মাধ্যমে কথা গোপন করা যায়.',
#  'মানুষ চিরস্থায়ী জীব.',
#  'যোগাযোগ থাকলে মানুষের সম্পর্কে পায় পূর্ণতা। ',
#  'মিথ্যা ভালোবাসা থেকে বিরত থাকাটা উত্তম। ',
#  'মনকে ভালো রাখার দায়িত্ব নিজের।',
#  'ভালোবাসা দেয়ার জন্য কোনো নিদৃষ্ট মানুষের থাকাটা প্রয়োজন',
#  nan,
#  'একাকিত্ব মানুষকে অনেক কিছু শিখায়। ',
#  'প্রত্যেক মানুষেরই একটা জীবন রয়েছে। ',
#  'কাউকেও ভালোবাসলে মন থেকে ভালোবাসা উচিৎ। ',
#  'ভালোবাসায় কষ্ট পাওয়াটা স্বাভাবিক। ',
#  'মেয়েদের মন বোঝা কঠিন। ',
#  'জেদ ভালোবাসাকে ধ্বংস করে। ',
#  'কাউকেও কোনো কিছুর মধ্যে আটকিয়ে রেখোনা। ',
#  'সমস্যার মুখোমুখি হওয়ার জন্য নিজেকে শক্ত  করো প্রয়োজন। ',
#  'ভালোবাসা বলার থেকে তা অনুভব করাটা জরুরী। ',
#  'কোনো কিছু না বলে শুধু ভালোবেসে যাওয়া অনেক বেশি সুন্দর।',
#  'একই পরিস্থিতির মধ্যে দিয়া কেউ না গেলে ,কেউ কখনো কারো কষ্ট বুঝে  না। ',
#  'মেয়েরা পুরুষদের  সম্পত্তি নয়  , তাদের সম্পদ',
#  'কষ্ট পেতে পেতে মানুষের গায়ে সয়ে যায় একদিন। ',
#  'কাছের মানুষকে সারাজীবন সাথে থাকার ভরসা দিন।',
#  'ভালোবাসার কোন নির্দিষ্ট দিবস নেই',
#  'ভালোবাসা  মানে দায়িত্ব, ভরসা, বিশ্বাস, প্রতিশ্রুতি রক্ষা করা।',
#  'পছন্দের মানুষ সারাজীবন সিঙ্গেল থাকুক,তাতেই শান্তি। ',
#  'খাওয়া ছাড়া কিচ্ছু না জীবনে',
#  'দুনিয়াতে সবাই পারফেক্ট হয়না, নিজের জন্য পারফেক্ট মানুষ নিজেকেই খুঁজে নিতে হয়। ',
#  'সময় চলে যায়।',
#  'প্রিয় মানুষ হতে হলে ,তার মন বুঝতে হবে আগে। ',
#  'মুভ অন করা মানে সব কিছু মেনে নিয়ে নতুন করে নিজেকে গুছিয়ে নেয়া',
#  'যাকে ভালো লাগে তার সব কিছুই ভালো লাগে। ',
#  'জীবনে কোনো কিছুই স্থায়ী না। ',
#  'ইচ্ছা থাকলে উপায় হয়। ',
#  'অধিকার হারানোর চেয়ে কষ্টের জিনিস আর কিছুই নাই। ',
#  'নিজেকে ভালোবাসতে শেখ। ',
#  'স্মৃতি গুলা ছড়িয়ে যাক। ',
#  'জীবনে কারো কথা শুনার জন্য হলেও কাউকে পাশে দরকার। ',
#  'জীবনে যেকোনো কাজই এমন ভাবে করা উচিত যাতে ঐটায় সেরা হওয়া যায়। ',
#  'এমন মানুষের সাথে আপনার প্রেম থাকবে যে আপনি নিজেও জানবেন না।',
#  'ছেলে মেয়ে সবাই সমানভাবে বাহিরে কাজ করতে পারা উচিত।',
#  'বেস্ট ফ্রেন্ড থাকা মানে অনেক কিছু।',
#  'বিচ্ছেদ মানুষকে শক্ত করে তুলে।',
#  'আল্লাহ যা করেন আমাদের ভালোর জন্যই করেন।',
#  'নারী চায় পুরুষের শেষ প্রেমিকা হতে।',
#  'জীবনতো  একটাই। ',
#  'টম এবং জেরী বিনোদনের একটি বড় মাধ্যম। ',
#  'মেয়েদের উত্তম পোশাক হলো শাড়ী। ',
#  'চুপচাপ মানুষগুলাও অনেক কথা বলতে চায়। ',
#  'আপনজনদের আগলে রাখতে শিখুন। ',
#  'মানুষ অবভ্যাসের দাস। ',
#  'সব মেয়ের জন্যই কেউ না কেউ রয়েছে।',
#  'ক্রিকেটের কাহিনী। ',
#  'সম্পক যত্ন করে রাখা উচিত। ',
#  'পুরোনো স্মৃতি গুলো মধুর হয়। ',
#  'কখনো হার মানা যাবে না।',
#  'অর্থবিত্তের জন্য প্রতিভা চাপা পরে যায়। ',
#  'ভালোবাসার জন্য লড়াই। ',
#  ' বিশ্বাস অবিশ্বাসের  খেলায় দিনশেষে অবিশ্বাস ই জিতে যায়।',
#  'সকল মানুষের  দৃষ্টিভঙ্গি আলাদা। ',
#  'চেষ্টা থাকলে উপায় হয় ',
#  'ইচ্ছা থাকলেই মনের ইচ্ছা পূরণ করা যায় না',
#  'কীর্তিমানের মৃত্যু নেই',
#  'নারীর ঘৃণা  মেনে মেনে নেয়া অনেক কঠিন। ',
#  'নিজেকে বিশ্বাস করো',
#  'সত্যিকারের ভালোবাসা কখনো ভুলা যায় না',
#  'সবাই বন্ধু হতে পারে না',
#  ' সত্যিকারের ভালোবাসা অমর ',
#  'ভাই বোনের সম্পর্ক অটুট',
#  'তুমি যাকে  চাও তার কাছে নয় , যে তোমাকে চায় তার কাছে যাও। ',
#  'কথা না থাকার পরও কথা হয়েছিল। ',
#  'যখন যার দরকার হয় তখন তাকে পাওয়া যায় না',
#  ' যখন যার প্রয়োজন তখন তাকে পাশে পাবেন না। ',
#  'নিজেকে সব পরিস্থিতিতে মানিয়ে নেওয়া শিখতে হবে। ',
#  'কখনো  কখনো  আত্মসম্মান নষ্ট করার চেয়ে নিজের কথা চিন্তা করা অনেক ভালো। ',
#  'সবার জীবনেই কেউ না কেউ আসবে।',
#  'মানুষের বিবেকবোধ নেই বললেই চলে। ',
#  'ভালোবাসা হলো সে যেমন তাকে তেমন ভাবেই ভালোবাসা।',
#  'প্রত্যেক মানুষেরই কোনো  না কোনো সঙ্গী থাকা  প্রয়োজন।',
#  'ভালোবাসার জন্য কোনো নিদৃষ্ট  দিনের প্রয়োজন হয় না। ',
#  'কখনো কখনো সময়ের সাথে সাথে মানুষগুলোই বদলে যায়। ',
#  'করো জন্য অপেক্ষা করার দরকার নেই। ',
#  'মানুষের পরিবর্তন হয়। ',
#  'কিছু মানুষ হুদাই সারারাত জেগে থাকে।',
#  'নারীরাই নারী জাগরণের প্রধান অন্তরায়',
#  'এই বঙ্গদেশের কিছু-কিছু আইন দেখে ঠাহর করা যায় না— এটি কত সাল; ২০১৪, না ১৯২১?',
#  'বাংলাদেশের বিশ্ববিদ্যালয়গুলো তথা গোটা বাংলাদেশ এখন আটকে আছে পঁচিশ পয়সার বৃত্তেই',
#  'এককালে আমরা প্রযুক্তিকে নিয়ন্ত্রণ করতাম, এখন প্রযুক্তিই আমাদেরকে নিয়ন্ত্রণ করছে',
#  'আদালত-চত্বরে এই ভুয়া ধর্ষিতাদের দৌরাত্ম্যে প্রকৃত ধর্ষিতারা বিচারবঞ্চিত হন',
#  'নারীর উপর নারীর নির্যাতন।  ',
#  'নারীরাই নারী জাগরণের প্রধান অন্তরায়',
#  'একজন নারীর হাতেও একজন নারী নিরাপদ না। ',
#  'নারীর অন্যতম শত্রূ নারীই',
#  'বর্তমানে পাঠকের চাইতে লেখকের সংখ্যা বেশি',
#  'বই শব্দটাকে পচিয়ে ছেড়েছে মৌসুমি লেখকের পাল',
#  'লেখক এর লেখা চুরি হয়ে যাওয়াঅবশ্যই কষ্টকর ও "শাস্তিযোগ্য',
#  'সুশীলরা বরাবরই দর্শক-পাঠকের মনোরঞ্জনে মাতোয়ারা',
#  'আমাদের ইতিহাস দাসত্বের ইতিহাস।',
#  'কাতুকুতু দিয়ে লোক হাসানো যায়, লোক কাঁদানো যায় না',
#  ' ৯ মাসে স্বাধীনতা পেয়ে যাওয়ায় এই সোনামাছ জাতি স্বাধীনতার মাহাত্ম্য বোঝেনি',
#  'এখনও অনেক বেঈমান এর মনে পাকিস্তান প্রীতি আছে',
#  'লেখার ক্ষেত্রে একজন লেখককে ভীষণ সৎ হতে হয়',
#  'মিথ্যে প্রশংসা কবিকে এতটাই বিভ্রান্ত করে যে,কোনো সত্যিকারের  প্রশংসাও তখন কবির কাছে মিথ্যে মনে হয়',
#  'লেখকের অসততা ধরা পড়ার পর পাঠকরা  মুখ ফিরিয়ে নেন',
#  'স্কুল জীবন মানুষ এর জীবন এর সব চাইতে সুন্দর সময়',
#  'বাংলার ইতিহাসে মহানায়কদের  একজন ছিলেন মাওলানা আব্দুল হামিদ খান ভাসানী',
#  'মানুষ আগেও পশু ছিলো এখনোও তাই। আগে শুধু প্রকাশ হতোনা, এখন হয়। পার্থক্য এখানেই',
#  'হবু মায়ের প্রতি চাই সহকর্মীদের সহযোগিতা।',
#  'মিথ্যাচার করে খুশি করার চেয়ে, সত্য বলে দুঃখ পাওয়া শ্রেয়',
#  'সকলের প্রতি সহ মর্মিতা ইসলাম আমাদের শিক্ষা দেয়',
#  'কিশোর বয়সের চাঞ্চল্য সব কিছুকে হার মানায়',
#  'কিশোর বয়সের চাঞ্চল্য সব কিছুকে হার মানায়',
#  'বই চুরি খারাপ নাহ তবে কারো মনে কষ্ট দিয়ে করা যাবে না ',
#  'চোরের দশ দিন তো গৃহস্থের এক দিন',
#  'দুনিয়াতে যাই ঘটুক কারো কারো কাজ হচ্ছে শুধু উপভোগ করা',
#  'বন্ধু শব্দটা যেমন পবিত্র তেমনি পবিত্র তার ধর্ম',
#  'বন্ধু শব্দটা যেমন পবিত্র তেমনি পবিত্র তার ধর্ম',
#  nan,
#  'ভালোবাসা সব ভালো মানুষ এর জন্য উন্মুক্ত না',
#  'বেঁচে থাকার জন্য সামান্য সামান্য কারনই যথেস্ট',
#  'গৌতম বুদ্ধ একজন জ্ঞানী',
#  'অ্যালকোহল বা ক্লোরিন শরীরের ভেতরে থাকা ভাইরাসের কিছুই করতে পারে না।',
#  'করোনা ভাইরাসে আক্রান্ত হবার সম্ভাবনা বয়-বৃদ্ধ, শিশু- কিশোর সবার আছে',
#  'করোনা ভাইরাসে উপসর্গ অনেকটাই ফ্লু জাতীয় ',
#  'করোনা ভাইরাসের মৃত্যু হার অনেক কম।',
#  'করোনা বিস্তারের জন্য যেকোনো বাহকই যথেষ্ট',
#  'করোনা ভাইরাস প্রতিরোধে মাস্ক এর পাশাপাশি সচেতনতাও জরুরী।',
#  'থার্মাল স্ক্যানারের মাধ্যমে করোনাভাইরাসের উপস্থিতি নির্ণয় সম্ভব',
#  'পুরান ঢাকা, ঢাকার সবচাইতে পুরাতন ইতিহাস বহন করে বয়ে চলছে।',
#  'নবাবপুর নামেও নবাব কাজেও নবাব। রাজা বাদশাহরা এই নবাবপুর হয়ে বিভিন্ন শহরে যাতায়াত করতেন। ',
#  'সূত্রাপুরে দারুশিল্প নির্মাণে সূত্রধররা বসবাস করতেন।',
#  nan,
#  'কেউ ছেড়ে গেলে জীবন থেমে থাকে না',
#  ' ভালোবাসা  অসীম',
#  ' চুপ থাকাটাও অনেক কষ্টের।   ',
#  ' কারো ব্যাক্তিত্বকে ভালোবাসা',
#  ' নিজেকে নিয়ন্ত্রণ করা জানতে হবে। ',
#  'নিজেকে নিজেরই গুছিয়ে নিতে হয়',
#  'ভালোবাসা  মানে  জোর  করে  আটকে  রাখা  না  ভালোবাসা  মানে  তাকে  ছেড়ে  দেয়াও। ',
#  'পাশে থাকার  মতো  একটি  বন্ধুই  যথেষ্ট। ',
#  'ভালোবাসার সম্পর্ক গুলো ভালো থাকুক',
#  ' ডেটিং এ যাওয়ার কিছু নিয়ম। ',
#  'ভালোবাসায় বিশ্বাস থাকা জরুরি। ',
#  ' দাঁত  থাকতে দাঁতের মর্ম বোঝে না। ',
#  ' নিজে ভালোতো জগৎ ভালো। ',
#  'না বলা ভালোবাসায় আসল ভালোবাসা। ',
#  ' দৃষ্টিভঙ্গি বদলালে, জীবন বদলে যাবে।',
#  ' ভালোবাসার মানুষকে অল্প দিয়েও খুশি করা যায়। ',
#  ' ভালোবাসার জন্য কোনো কারণ লাগে না। ',
#  ' মেয়েরা চাইলে সব করতে পারে। ',
#  ' চেষ্টা না করেই হারমানা  উচিত না। ',
#  ' ভালো সময় গুলো  কিছু ভালোবাসার মানুষের সাথে কাটালে মনটা আরো ভালো হয়ে যায়। ',
#  ' যে তোমাকে গুরুত্ব দিবে না , তাকে গুরুত্ব দেওয়ার প্রয়োজন নেই। ',
#  'ভালোবাসা একবার নষ্ট হয়ে গেলে তা আর ফেরানো যায় না।',
#  ' একাকীত্বতা অনেক কষ্টের। ',
#  ' কাউকে পেতে হলে অনেক কষ্ট করে পেতে হয়।',
#  'কাউকে ভালো লাগলে তাকে বলে দিতে হয় তাহলে সারা জীবন আফসোস করতে হয়।',
#  ' ভালোবাসতে জানলে ভালোবাসতে শেখো।',
#  ' যত বড় হচ্ছি জীবনে ভুলের মাত্রা বেড়ে যাচ্ছে',
#  ' অবহেলা মানুষের পিছু ছাড়ে না। ',
#  'মন মরে গেছে এটা বোঝার উপায়।',
#  ' সব দিক দিয়ে বেস্ট হতে হবে না আমাকে ভালোবাসলেই হবে। ',
#  ' ভালো বন্ধু পাওয়া ভাগ্যের ব্যাপার। ',
#  'কখনো আত্মসম্মান নষ্ট করতে নেই। ',
#  ' এক্সদের  বিয়া হয়ে যাওয়া ভালো। ',
#  ' সবারই মন আছে , তাই প্রেম করতে ইচ্ছা করে। ',
#  ' এক সময় মনে হবে আপনি আগে অনেক বোকামি করতেন। ',
#  ' আগামী কালের জন্য আমরা সব কিছু ফেলে রাখি।',
#  ' মানুষ গুলো একই থাকে শুধু সময়টা বদলে যায়',
#  ' ভালোবাসার মানুষকে এখন সবাই "প্রাক্তন" নাম জানে। ',
#  ' কারো জন্য অপেক্ষা করে লাভ নেই। ',
#  'কিছু মানুষ  কোনো কারণ ছাড়াই সারারাত জেগে থাকে ',
#  ' প্রেম করিনি , ভালোবেসেছি। ',
#  ' জোর করে না ভুলার চেষ্টা  করার  দরকার নেই , একদিন এমনেই ভুলে যাবেন। ',
#  'অতিমুনাফার জন্য মাস্ক মজুদ করে রাখা। ',
#  'হ্যান্ড স্যানিটাইজার পিছনে না ছুটে সাবান দিয়ে হাত পরিষ্কার করুন ।',
#  ' প্রেম নয় ভালোবাসা দরকার। ',
#  'নারীদের প্রতি সম্মান দেখানো উচিত। ',
#  'মন থেকে নারীর প্রতি সম্মান থাকতে হবে , ফেসবুকে স্ট্যাটাস দিয়ে নয়। ',
#  'নারীর সমান অধিকার চাওয়া হয়েছে। ',
#  ' অন্যকে জাজমেন্ট না করে  নিজের সময়কে কাজে লাগান। ',
#  'আমরা নারীরা , চাইলেই সব পারি। ',
#  ' নারীকে সম্মান করা উচিত বছরের প্রতিটি  দিনই।',
#  ' ছোটখাটো ভুলের জন্য সম্পর্ক নষ্ট হয়ে যায়। ',
#  'নারী দিবেস বিশ্বের সকল নারীকে  শুভেচ্ছা জানানো হয়েছে । ',
#  'টাকা খরচ ছেলেদের কাজ না , মেয়েরা ছেলেদের পিছনে টাকা খরচ  করতে পারে। ',
#  ' নারীরা নিজেকে নিয়ন্ত্রণ করতে পারলে পুরুষের ও উচিত নিজেকে নিয়ন্ত্রণ  করা। ',
#  ' চিঠি দিয়ে প্রেম করার মজাই আলাদা। \n',
#  ' মেয়েদের পড়াশোনা করানো উচিত',
#  ' একুশ বছরের মেয়েদের প্রেম করা মানা কারণ তাকে বিয়ে করতে হবে ঐসময়।',
#  ' বাস্তবতা আর সিনেমা এক নয়। ',
#  'ভালো মানুষের দাম নাই',
#  '  বঙ্গবন্ধুর ৭ মার্চের ভাষণ।',
#  ' সৌন্দর্য শুধু উপর দিয়ে হয় না , ভিতরের  সৌন্দর্য আসল সৌন্দর্য',
#  ' যার মন ভালো সেই প্রকৃত  সুন্দর',
#  ' অল্পতেই সুখী হওয়া যায়।',
#  '  মনুষ্যত্বহীন মানুষ কখনো ভাল মানুষ হতে পারে না।',
#  ' মানুষ যা চায় তা পায় না',
#  ' ধর্যের ফল মিষ্টি হয়',
#  ' মনের কথা শোনার  মতো কেউ থাকে না। ',
#  ' খারাপ অবস্থায় যে ভালোবাসে সেই ভালোবাসা  আসল। ',
#  ' দোষ না করেও যে স্যরি বলে, তাকে ধরে রাখুন। ',
#  ' পাশের বাড়ির ছেলে মেয়েরা অনেক ভালো রেজাল্ট করে ',
#  ' ফ্যামিলির্ উপর আপনজন আর কেউই নেই।',
#  ' বিয়ের পর রোমান্টিক না হওয়ার অভিযোগ।',
#  ' ভালোবাসা পাল্টায় না, প্রকাশ এর ধরণ পাল্টায়',
#  ' করোনা ভাইরাস সম্পর্কে কিছু কথা। ',
#  ' ভালোবাসার গভীরতা',
#  ' ভালোবাসা কাকে বলে সে চিনে। ',
#  ' কেউ একজন আসবে  যে সবার মতো থাকবে না',
#  ' তুমি না থাকলে ভালোবাসা জন্মতোই না',
#  ' প্রযুক্তির যুগে এসে  নাটকের সব ইমোশন গুলা নষ্ট করে দিয়েছে। ',
#  ' কারো প্রতি নির্ভরশীল হওয়া যাবে না',
#  'অভিমানের চেয়ে খারাপ কিছু আর হতে পারে না',
#  ' ভালো লাগার কোনো কারণ নেই',
#  ' যে আপনাকে খুশি করতে চাবে  ,এর থেকে সুখ আর কিছুই  নেই',
#  ' কুসংস্কার থেকে মেয়েদের মুক্তি দিতে হবে।',
#  ' ছোটখাটো জিনিস এর মধ্যে ভালোবাসা থাকে',
#  ' ভালোবাসতে হলে আগে সব হিসাব করেই ভালোবাসতে হবে',
#  ' এমন মানুষ দরকার যে সারাজীবন পাশে থাকবে',
#  ' ভালোবাসার মানুষের সব খবর রাখা ,সে কার সাথে কথা বলে চলে',
#  ' ভালোবাসা ভাঙ্গার কষ্ট অনেক ',
#  ' ভালোবাসা কখনো ভোলা যায়  না। ',
#  ' সারাদিন কষ্ট করে ভালোবাসার মানুষের ছোট চাওয়া।',
#  ' দৃষ্টিভঙ্গি পরিবর্তন করুন।',
#  ' এমন কেউ থাকে যারা শুধু মানুষকে ভালো রেখেই যায়। ',
#  ' ভালোবাসি কোঠাটান বলার জন্য ও একজন মানুষ দরকার। ',
#  ' বেশি কিছু ছাড়াও  সুখী হওয়া যায়। ',
#  ' কাউকে  পাওয়ার আকুল বাসনা। ',
#  ' ভালোবাসতে হবে না ,আমি ভালোবেসে যাই। ',
#  ' এই প্রজন্ম থেকে কোনো বুদ্ধিজীবী পাওয়া কঠিন। ',
#  '৩ মার্চ এর তাৎপর্য',
#  ' পাবনা জেনেও  ভালোবেসে যাওয়া। ',
#  ' এক্সদের  বিয়া হয়ে যাওয়া ভালো। ',
#  ' সবারই মন আছে , তাই প্রেম করতে ইচ্ছা করে। ',
#  ' এক সময় মনে হবে আপনি আগে অনেক বোকামি করতেন। ',
#  ' আগামী কালের জন্য আমরা সব কিছু ফেলে রাখি।',
#  ' মানুষ গুলো একই থাকে শুধু সময়টা বদলে যায়',
#  ' ভালোবাসার মানুষকে এখন সবাই "প্রাক্তন" নাম জানে। ',
#  ' কারো জন্য অপেক্ষা করে লাভ নেই। ',
#  'কিছু মানুষ  কোনো কারণ ছাড়াই সারারাত জেগে থাকে ',
#  ' প্রেম করিনি , ভালোবেসেছি। ',
#  ' জোর করে না ভুলার চেষ্টা  করার  দরকার নেই , একদিন এমনেই ভুলে যাবেন। ',
#  'অতিমুনাফার জন্য মাস্ক মজুদ করে রাখা। ',
#  'হ্যান্ড স্যানিটাইজার পিছনে না ছুটে সাবান দিয়ে হাত পরিষ্কার করুন ।',
#  ' প্রেম নয় ভালোবাসা দরকার। ',
#  'নারীদের প্রতি সম্মান দেখানো উচিত। ',
#  'মন থেকে নারীর প্রতি সম্মান থাকতে হবে , ফেসবুকে স্ট্যাটাস দিয়ে নয়। ',
#  'নারীর সমান অধিকার চাওয়া হয়েছে। ',
#  ' অন্যকে জাজমেন্ট না করে  নিজের সময়কে কাজে লাগান। ',
#  'আমরা নারীরা , চাইলেই সব পারি। ',
#  ' নারীকে সম্মান করা উচিত বছরের প্রতিটি  দিনই।',
#  ' ছোটখাটো ভুলের জন্য সম্পর্ক নষ্ট হয়ে যায়। ',
#  'নারী দিবেস বিশ্বের সকল নারীকে  শুভেচ্ছা জানানো হয়েছে । ',
#  'টাকা খরচ ছেলেদের কাজ না , মেয়েরা ছেলেদের পিছনে টাকা খরচ  করতে পারে। ',
#  ' নারীরা নিজেকে নিয়ন্ত্রণ করতে পারলে পুরুষের ও উচিত নিজেকে নিয়ন্ত্রণ  করা। ',
#  ' চিঠি দিয়ে প্রেম করার মজাই আলাদা। \n',
#  ' মেয়েদের পড়াশোনা করানো উচিত',
#  ' একুশ বছরের মেয়েদের প্রেম করা মানা কারণ তাকে বিয়ে করতে হবে ঐসময়।',
#  ' বাস্তবতা আর সিনেমা এক নয়। ',
#  'ভালো মানুষের দাম নাই',
#  '  বঙ্গবন্ধুর ৭ মার্চের ভাষণ।',
#  ' সৌন্দর্য শুধু উপর দিয়ে হয় না , ভিতরের  সৌন্দর্য আসল সৌন্দর্য',
#  ' যার মন ভালো সেই প্রকৃত  সুন্দর',
#  ' অল্পতেই সুখী হওয়া যায়।',
#  '  মনুষ্যত্বহীন মানুষ কখনো ভাল মানুষ হতে পারে না।',
#  ' মানুষ যা চায় তা পায় না',
#  ' ধর্যের ফল মিষ্টি হয়',
#  ' মনের কথা শোনার  মতো কেউ থাকে না। ',
#  ' খারাপ অবস্থায় যে ভালোবাসে সেই ভালোবাসা  আসল। ',
#  ' দোষ না করেও যে স্যরি বলে, তাকে ধরে রাখুন। ',
#  ' পাশের বাড়ির ছেলে মেয়েরা অনেক ভালো রেজাল্ট করে ',
#  ' ফ্যামিলির্ উপর আপনজন আর কেউই নেই।',
#  ' বিয়ের পর রোমান্টিক না হওয়ার অভিযোগ।',
#  ' ভালোবাসা পাল্টায় না, প্রকাশ এর ধরণ পাল্টায়',
#  ' করোনা ভাইরাস সম্পর্কে কিছু কথা। ',
#  ' ভালোবাসার গভীরতা',
#  ' ভালোবাসা কাকে বলে সে চিনে। ',
#  ' কেউ একজন আসবে  যে সবার মতো থাকবে না',
#  ' তুমি না থাকলে ভালোবাসা জন্মতোই না',
#  ' প্রযুক্তির যুগে এসে  নাটকের সব ইমোশন গুলা নষ্ট করে দিয়েছে। ',
#  ' কারো প্রতি নির্ভরশীল হওয়া যাবে না',
#  'অভিমানের চেয়ে খারাপ কিছু আর হতে পারে না',
#  ' ভালো লাগার কোনো কারণ নেই',
#  ' যে আপনাকে খুশি করতে চাবে  ,এর থেকে সুখ আর কিছুই  নেই',
#  ' কুসংস্কার থেকে মেয়েদের মুক্তি দিতে হবে।',
#  ' ছোটখাটো জিনিস এর মধ্যে ভালোবাসা থাকে',
#  ' ভালোবাসতে হলে আগে সব হিসাব করেই ভালোবাসতে হবে',
#  ' এমন মানুষ দরকার যে সারাজীবন পাশে থাকবে',
#  ' ভালোবাসার মানুষের সব খবর রাখা ,সে কার সাথে কথা বলে চলে',
#  ' ভালোবাসা ভাঙ্গার কষ্ট অনেক ',
#  ' ভালোবাসা কখনো ভোলা যায়  না। ',
#  ' সারাদিন কষ্ট করে ভালোবাসার মানুষের ছোট চাওয়া।',
#  ' দৃষ্টিভঙ্গি পরিবর্তন করুন।',
#  ' এমন কেউ থাকে যারা শুধু মানুষকে ভালো রেখেই যায়। ',
#  ' ভালোবাসি কোঠাটান বলার জন্য ও একজন মানুষ দরকার। ',
#  ' বেশি কিছু ছাড়াও  সুখী হওয়া যায়। ',
#  ' কাউকে  পাওয়ার আকুল বাসনা। ',
#  ' ভালোবাসতে হবে না ,আমি ভালোবেসে যাই। ',
#  ' এই প্রজন্ম থেকে কোনো বুদ্ধিজীবী পাওয়া কঠিন। ',
#  '৩ মার্চ এর তাৎপর্য',
#  ' পাবনা জেনেও  ভালোবেসে যাওয়া। ',
#  'একজন কবি বা লেখকের শেষ জীবন বড়ই কষ্টের',
#  'মৃত্যুর আগে মানুষকে তার প্রাপ্য সম্মানটুকু দিতে হবে',
#  'মানুষ নিজের প্রয়োজনে মানুষ কে কাছে টেনে নেয় কাজ শেষে আবার দূরে ছুড়ে ফেলে দেয়',
#  'নির্বাহী ম্যাজিস্ট্রেটদের বিচারিক ক্ষমতা প্রত্যাহার করে এই ক্ষমতা কেবল জুডিশিয়াল ম্যাজিস্ট্রেটদের হাতে রাখা উচিত ',
#  'মানুুষ ক্ষেতি পেয়ে নিজের অতীতকে ভুলে যায়',
#  'কবি হবে বিনয়ী— বিনয়ের ভাণ্ডার',
#  'কবিিদের এই সমাজে নিরীহ ও তুচ্ছ তাচ্ছিল্যর চোখে দেখা হয়',
#  'কবিরা দিনশেষে তাদের প্রাপ্য সম্মানী পান না এই দেশে',
#  'অন্যের মেধা চুরিকারিদের এই দেশে বিচার হয় না',
#  'এই দেশে কবিদের বাক স্বাধীনতা নেই',
#  'কবি হবে উদারমনা',
#  'এই বাংলাদেশ স্বৈরাচারী কবি দেখতে চায় না, বাংলাদেশ কবিকে দেখতে চায় সবাইকে একসাথে খুশি রাখা পতিতারূপে।',
#  'কবি হবে সর্বজনের ক্রীতদাস',
#  'বাংলাদেশে কবিকে হতে হবে সর্বরোগবিশেষজ্ঞ',
#  'করোনার কারনে ইতালি এখন মৃত্যুপুরী',
#  'গঠনমূলক সমালোচনা মানুষ মেনে নিতে পারে না',
#  'লেখক হতে চায় কিন্তু পরিশ্রম করতে চায় না',
#  'লেখক হতেে হলে হতে হবে যোগ্যতাসম্পন্ন লেখক',
#  'কখন কোথায় কি প্রশ্ন করতে হয় সে সম্পর্কে স্পষ্ট ধারনা থাকতে হবে',
#  'বাঙালি জাতির বিবেকের চেয়ে আবেগ বেশি কাজের চেয়ে কথা বেশি',
#  'দিনশেষে আমরা সবাই খুব একা',
#  'করোোনাতে আক্রান্ত ব্যাক্তির মৃত দেহ দাফন বা সৎকার খুবই বেদনাদায়ক',
#  "হঠাত করে কাউকে 'আমি কে' প্রশ্ন করা ঠিক না",
#  'সত্যি বলতে টেকনােলজিক্যালি ডিলিট বলতে কিছু নেই',
#  'তিন বিভাগের কর্মকাণ্ডে সমন্বয় থাকলে রাষ্ট্র সুস্থ থাকে, না থাকলে রাষ্ট্র অসুস্থ হয়ে পড়ে।',
#  'প্রধানমন্ত্রীর নির্দেশ এখন নির্বিষ ও নিরামিষ হয়ে যাচ্ছে।',
#  'করোনাা ভাইরাসের বেপারে আমাদের অনেক বেশি সচেতন হতে হবে',
#  'পারসেন্ট আর শতকরা একই কথা',
#  "সহৃদয়বান' না লিখে 'হৃদয়বান' বা 'সহৃদয়' লিখতে হবে",
#  'মূল্য মানেই দাম, দাম মানেই মূল্য',
#  'কাল মানে সময়, সময় মানে কাল',
#  'ইভেন অর্থ এমনকি। তাই কথার মাঝে ইভেন ব্যাবহার করা গেলেও ইবেনকি ব্যাবহার ঠিক না',
#  'লাশ জীবিত হয় না, মৃতই হয়',
#  'বহুবচন এর সাথে রা, দের বা গুলো যোগ করা যাবে না।',
#  'মর্নিং ওয়াক মানেই সকালের হাঁটাহাঁটি',
#  "সকল' কথাটি বললে তৎপরবর্তী শব্দটিকে আর বহুবচন বানানো যাবে না।",
#  'রিপিট করা মানেই আবার ঘটানো',
#  "সাবেক' মানেই 'অতীতে ছিল এমন কিছু'",
#  "কনিষ্ঠ মানেই সবচেয়ে ছোট, জ্যেষ্ঠ মানেই সবচেয়ে বড়, এদের সাথে 'তম' যোগ করা যাবে না",
#  'বেস্ট মানেই সবচেয়ে ভালো',
#  'লেটেস্ট মানেই সর্বশেষ',
#  "ভ্যাকেন্সি মানেই 'খালি",
#  'এইদেশের প্রতিটি পদে অযোগ্যদের  অবস্থান',
#  'এখন লেখক হতে হলে মেধা না দরকার ফ্যান ফলোয়ার',
#  'লেখকের লেখালেখি কোনো পেশার মধ্যে পড়ে না এই সমাজের চোখে',
#  'মেধা থাকুক আর না থাকুক আমারা নিজেদের লেখক হিসাবে ধরে নেই',
#  'লেখক হলেই যে আপনাকে পদক পেতে হবে এমন কোনো বাধ্যবাধকতা নেই',
#  'লেখকের লেখাালেখি পেশা হিসাবে মেনে নিতে আমাদের সমাজে এখনো অনেক অগ্যতা রয়েছে',
#  'লেখকদের পদে-পদে অপদস্থ করতে বাঙালি বদ্ধপরিকর',
#  'কুলখানি নিছক আমাদের নিজেদের বানানো একটা  রীতি',
#  'মধ্যবিত্ত পরিবারগুলোয় আয়োজন আছে, আড়ম্বর নেই; অনানুষ্ঠানিক আবেগ আছে, আবেগের আনুষ্ঠানিক প্রকাশ নেই',
#  'মধ্য্যবিত্ত পরিবারের সন্তানেরা তাদের আবেগের সবটুকু প্রকাশ করতে পারে না',
#  'অসুখ না হলে মধ্যবিত্ত পরিবারের সন্তানের কপালে মায়েদের হাত পড়ে না',
#  ' বিজ্ঞান যুক্তি ও প্রমানের উপর প্রতিষ্ঠিত আর ধর্ম বিশ্বাসের উপর প্রতিষ্ঠিত।',
#  'কোনো মাধ্যমের মধ্যে চার্জিত কণা(e‐ Electron) সেই মাধ্যমের আলোর বেগ অতিক্রম করে আর নীল আলো ছড়িয়ে দেয়; একেই চেরেনকভ বিকিরণ বা রেডিয়েশন বলা হয়!',
#  'সেটা অতীতের ভিউ, কেননা আলো পৃথিবীতে আসতে আসতে সময় লাগে, এখন এই তারার সামনে দিয়ে যদি কোন ধূমকেতু বা গ্রহ যায়, তখন আলো বাধাপ্রাপ্ত হবে, মনে হবে মিট-মিট করলো',
#  'মস্তিষ্ক হল কেন্দ্রীয় স্নায়ুতন্ত্রের একটি অপরিহার্য অংশ যা মানুষের সমস্ত কিছু নিয়ন্ত্রন করে। ',
#  'ফোটন তড়িৎ চৌম্বকীয় বল বা ক্ষেত্রের সমার্থক। ',
#  "কোয়ান্টাম তত্ত্বের মূল কথা হচ্ছে, প্রকৃতির উপাদান গুলোকে ভাঙলে মূল কণিকা গুলো অর্থ্যাৎ 'ইলেকট্রন, প্রোটন এবং নিউট্রন' পাওয়া যাবে। কিন্তু স্ট্রিং থিওরি বলে, এই মূল কণিকা গুলো হচ্ছে এক ধরনের তন্তু বা সুতার কম্পন। এই সুতা বা স্ট্রিং গুলোর বিভিন্ন মোডে কম্পনের কারনেই সেগুলোকে কণা হিসেবে আমরা দেখছি। এবং এই কম্পন প্রতিটি পদার্থের জন্য ভিন্ন। তাই প্রতিটি পদার্থই ভিন্ন ধর্ম প্রদর্শন করে। এমনকি প্রতিটি পদার্থের ভরও এই স্ট্রিং গুলোর কম্পনের ওপর নির্ভর করে।",
#  'বৃহস্পতি গ্রহ সূর্যকে কেন্দ্র করে ঘুরে না।',
#  'বিজ্ঞান হোক সহজ, বিজ্ঞান পৌঁছে যাক ঘরে ঘরে।',
#  'মহাবিশ্বের বিশালতার মাঝে আমরা খুবই ক্ষুদ্র।',
#  '৬৪০ আলোকবর্ষ দূরে পাওয়া গ্রহে বৃষ্টির মতো ঝরে পড়ে লোহা।',
#  'সূর্যের চারদিকে গ্রহ ঘুরার করণ এই নয় যে, সূর্য থেকে মহাকর্ষ এসে পৌঁছায় বরং স্পেসটাইমের কারণে বাক সৃষ্টি হয়, গ্রহগুলো সেই বাক বেয়ে ঘুরে।',
#  'আলোর বেগে গতিশীল হলে সময় কেন থেমে যায়',
#  'মঙ্গল গ্রহের ভিতর ধারনা করা হচ্ছে পানি পাওয়া সম্ভব তা জীবন ধারনের জন্য অনুকুল বলাই বাহুল্য।',
#  'পাই এর গুরুত্ব অপরিসীম এই মহাবিশ্বে।',
#  'গ্রহ যেমন বড় তার শক্তি ধারন ক্ষমতা ততবেশি সাথে থিউরি অফ রিলেটিভিটির চমকতো থাকছেই।',
#  'ব্ল্যাক হোল শক্তির বড় আধাঁর, এর মধ্য দিয়ে আলো বের হবার মতো শক্তি আলোর নেই কারন গ্রাভিটি অনেক ব্ল্যাক হোলের।',
#  'এটি একটি টেলিস্কোপের নাম সাথে ব্ল্যাক হোলের বিন্দুর নাম।',
#  '২০-৩০ লক্ষ ডিগ্রি কেলভিন তাপমাত্রায় হাইড্রোজেন গ্যাসের পরমাণুগুলো বিচ্ছিন্ন হয় এবং প্রোটন ও ইলেকট্রনের গ্যাস হিসেবে অবস্থান করে',
#  'এডউইন হাবল"-এর নাম অনুসারে হাবল টেলিস্কোপের নামকরণ করা হয়েছিল',
#  'পূর্ণবিকশিত বা ম্যাচুউরড অবস্থায় একটি নক্ষত্র কতদিন বেঁচে থাকবে তা মূলত নির্ভর করে এর শক্তির উপর।',
#  'ভালোবাসার মানুষ অনেক সময় অনেক ভালোবাসা প্রকাশ করতে পারে না, কিন্তু সে যে ভালোবাসে না তা বলা যাবে না।',
#  'ভালোবাসার মানুষ কখনোই চায় না নিজের সংগিনীকে ছেড়ে দিতে।',
#  'আকাশগঙ্গা একটি ছায়াপথ। সৌরজগতের কেন্দ্র সূর্য এই ছায়াপথের অংশ। অর্থাৎ আমরা থাকি এই ছায়াপথে। এটি একটি সর্পিলাকার ছায়াপথ।',
#  'করোনা ভাইরাস মোকাবিলায় সবার সচেতন থাকতে হবে পাশাপাশি আল্লাহর ইবাদাত করতে হবে।',
#  'করোনা ভাইরাস এর সবচাইতে বড় ভ্যাক্সিন "সচেতনতা"।',
#  'করোনা ভাইরাস মোকাবিলায় ফেইসবুকের সঠিক ব্যবহার বাধ্যতা মুলক।',
#  'ভারত বর্তমান ক্রিকেট এর বিধাতা',
#  'নিজেদের প্রভাব বজায় রাখতে ভারত চীনকে ক্রিকেট থেকে দূরে রাখছে',
#  'অর্থের উত্তাপে ভারত আম্পায়ারদেরকে করেছে সেবাদাস। ',
#  'ক্রিকেটবিশ্বে ভারত এখন কনেরও মামাশ্বশুর, বরেরও চাচাশ্বশুর।',
#  'ভারত ব্যবসা শিখল, সৌজন্য শিখল না।',
#  'আইপিএল সমূলে ধ্বংস করেছে ক্রিকেটের মৌলিকতা',
#  'শুধু ভাইরাসই শক্তিশালী হচ্ছে না,মূর্খরাও শক্তিশালী হচ্ছে',
#  'দক্ষিণ কোরিয়া শিক্ষা ও গবেষণা এবং স্বাস্থ্যে পৃথিবীর সর্বোচ্চ বরাদ্দ দেওয়া দুই তিনটি দেশ অন্যতম।',
#  'করোনো টেস্ট কিট বাংলাদেশে আবিস্কার হয়েছে',
#  'উট পাখির মত মাটিতে মুখ লুকিয়ে স্বল্প সময়ের জন্য কিছু মানুষকে বোকা বানানো যাবে কিন্তু সব সময় না।',
#  'আমাদের মেয়ররা কার্যত অকার্যকর',
#  'করোোনার বিরুদ্ধে আমাদের প্রস্তুতি শূন্যের গোড়ায়',
#  'আমাদের শিক্ষা ও স্বাস্থ্য খাতে বরাদ্দ অতি নগন্য',
#  'করোনোার ভয়াবহতা আমরা অনুধাবন করতে পারছি না',
#  'বিদেশ ফেরতদের কোয়ারান্টিনের গুরুত্ব বোঝাতে আমরা ব্যাথ',
#  'যে দেশ যত বেশি সভ্য সেই দেশ জাতীয় রিস্ককে তত বেশি গুরুত্ব দেয়',
#  'বিশ্ববিদ্যালয় গুলোর গণরুম বসবাস অযোগ্য ',
#  'জাতি হিসাবে আমরা বড়ই অসভ্য',
#  'একটা নির্দিষ্ট পরিমান টাকা মজুদ থাকার পর টাকা থাকা আর না থাকা একই কথা',
#  'টেক জায়ান্টদের মধ্যে গেটসকেই সবচেয়ে মানবতাবাদী এবং ভিশনারি মনে হয়।',
#  'মানুষ করোনা নিয়ে গুজব ছড়াতে ব্যস্ত',
#  'আমরা এই দেশের গুনীদের নানা উপায়ে অপমান করতে ব্যস্ত ',
#  'আমরাা সুযোগ পেলেই অসৎ পথে চলার চেষ্টা করি',
#  'আমাদের ভেজাল খাদ্যভাস এর জন্য অল্প বয়সে আমাদের নানা রোগে আক্রান্ত হতে হয়',
#  'অতিরিক্ত ভেজাল খাওয়ার ফলে এই দেশের মানুষের শরীরে প্রাকৃতিকভাবেই এক ধরণের ইমিউনিটি ডেভেলপ করেছে',
#  'হোম কোয়ারেন্টাইনে থাকা অবস্থায় বাসায় বসে নাটক সিনেমা দেখে সময় কাটানো যায়',
#  'আমাদেের করো না সনাক্তকরনের যথেষ্ট টেস্ট কিট নেই',
#  'করোনা নিয়ে সবার মধ্যে আতঙ্ক থাকলেও কারো মধ্যে কোনো সচেতনতা নেই',
#  'দেশের ক্রান্তিকালে সবাইকে  সচেতন হতে হবে',
#  'করোনা ভাইরাসের বিরুদ্ধে কোনো প্রটোকল ই এই দেশে মানা হচ্ছে না',
#  'নারী দিবস নিয়ে অনেকেই আমরা তুচ্ছ তাচ্ছিল্য করি',
#  'হোয়াইট বোর্ড আর মার্কার পরিবেষ দূষোণেড় জন্য দায়ী',
#  '২০ শতাংশ মানুষই সকল ভালো কাজের নির্ণায়ক',
#  'ভারত এবং বাংলাদেষ দুই দেশের মধ্যে ধর্ম নিয়ে এক অদ্ভুদ মিল আছে',
#  'সান্ধ্যকালীন প্রোগ্রাম কোন ব্যাধি না ওটাও উপসর্গ',
#  'অনৈতিক শিক্ষকের কাছে পড়া শিক্ষার্থীরা ও এখন নৈতিকতার ধার ধারে না',
#  'পড়াশুনা কখনো লাভলোকশানের কথা ভেবে করা উচিত নয়',
#  'বাংলাদেশে মানুষ করোনাকে সেলুকাসে পরিনত করেছে',
#  'করোনায় আক্রান্ত রোগীদের সেবা দেয়ার জন্য ডাক্তারদের যথেষ্ট প্রোটেক্টিভ গিয়ার নেই',
#  'প্রস্তুতি নেয়ার অনেক সময় পেয়েও বাংলাদেশ করোনা সনাক্তকরনের টেস্ট কিট মজুদ করেনি',
#  'মায়ানমার ও উত্তর কোরিয়া করোনায় আক্রান্তদের গুলি করে মেরে ফেলছে',
#  'এক্সপোনেনশিয়াললি বাড়া মানে সময়ের সমান দূরত্বে আক্রান্তের সংখ্যা দ্বিগুন আকারে বাড়ে।',
#  'বাংলাদেশে  বিচারিক কাজে নগ্ন হস্তক্ষেপ চলে ',
#  'ঢাকা বিশ্বের সবচেয়ে দূষিত শহর',
#  ' দুর্নীতি বাজদের জন্য এই দেশ এখনো পিছিয়ে',
#  'শিশু কিশোরদের ঘৃনা শেখানো উচিত না । ',
#  'খারাপকে খারাপ ভালো কে ভালো বলতে হবে সেখানে ধর্ম,জাতি,দেশ দেখা চলবে না',
#  'একজন ফ্রেশ গ্রেজুয়েট বিশ্ববিদ্যালয়ের শিক্ষক হতে পারে না',
#  'এইদেশ কখনো যোগ্যদের সঠিক সম্মান দিতে পারে নি',
#  'ভালোবাসার যত্ন নিতে হয়।',
#  ' মিথ্যা ভালোবাসা থেকে বিরত থাকা',
#  ' চোখের পানি সব দুঃখকে  ভাসিয়ে দিতে পারে।',
#  ' ভালোবাসা জীবনের সত্যি গুলোকে  সামনে নিয়ে আসে',
#  'এক বছর হতে সময় লাগে ৩৬৫ দিন ৫ ঘন্টা ৪৮ মিনিট ৪৫.৯৭ সেকেন্ড।',
#  '  সত্যিকারের ভালোবাসা পাওয়া কঠিন',
#  ' বৃদ্ধ বাবা মায়ের প্রতি ভালোবাসা',
#  ' ভালোবাসার মানুষ না পাওয়ার কষ্ট',
#  ' সময় কাটানোর একটি মাধ্যম',
#  ' আমি তো  দাড়িয়ে আছি',
#  'সব কিছুর উর্ধে আত্মসম্মান বোধ থাকা জরুরি',
#  'খারাপ সময় গুলোতে পাশে থাকা',
#  ' কোনো কিছু দ্বিতীয় বার করায় কোনো লজ্জা নেই',
#  ' দেশের পপ সম্রাট আজম খানের জন্মদিন',
#  ' মানুষের মধ্যে শ্রোতার মনোভাবটির অভাব',
#  ' বিয়েতে দেনমোহর জিনিসটা এখন দম্ভ দেখানোর মতো হয়ে গেছে।',
#  ' বয়স বৃদ্ধির সাথে সাথে মানুষের বুঝার ক্ষমতাটাও বেড়ে যায়',
#  ' সময়ের সাথে সাথে মানুষের জীবনের সব কিছুই বদলে যায়',
#  ' মানুষ তার কর্মের জন্য দায়ী',
#  ' কোনো মানুষকে  ছেড়ে আসার পর সে আর আমাদের থাকে না',
#  ' যারা গরিব তাদের জীবনে দুঃখ কষ্ট সব সময়ের জন্য',
#  ' সত্যিকার ভালোবাসার মানুষটি জীবনে একবারই আসে',
#  ' অনুভুতি গুলো সব সময় থেকে যায়',
#  ' মানুষকে জোর করে আটকে রাখা যায় না ',
#  ' ১৮ বসরে করণীয় উপদেশ',
#  ' ভালোবাসা শুধু মাত্রই একটি অনভুতি',
#  'প্রিয় হয়ে উঠতে হলেও যোগ্যতার প্রয়োজন\n',
#  'দুঃসময়ে পরিপূর্ণভাবে পাশে থাকায় হচ্ছে ভালোবাসা।',
#  ' মানুষ  কখনোই  একটি  মৌলিক  মানুষকে  ভালোবাসতে  পারে  না ',
#  ' অরুণিমা শাবির মধ্যেই লুকিয়ে আছে। ',
#  'মেয়েরা তাদের অধিকার থেকে বঞ্চিত',
#  ' অনেকেই  তার  ভালোবাসার  মানুষকে  ধোকা দেয়।  ',
#  ' একটি সম্পর্ককে টিকিয়ে রাখতে হলে দুই দিক থেকেই বলিদান দেয়া প্রয়োজন। ',
#  ' বইয়ের  সাদা  পাতার  আবেগ  গুলো  খুব  প্রাণময় ',
#  ' স্কুল  জীবনের  স্মৃতি  সকলের  কাছেই  অমূল্য ',
#  " বাচ্চাটি দু'বার জন্মেছে ",
#  ' জীবনকে উপভোগ করার জন্য সব  কিছুই আবশ্যক  ',
#  ' আমি শুধু তোমারি হতে চাই ',
#  'সকলের ভাগ্যে প্রকৃত ভালবাসার মানুষ থাকে না',
#  ' শুধু মেরে ফেলাকে খুন বলে না ,মানুষের মন ভাঙ্গাকেও খুন বলে',
#  ' একজন মানুষের প্রতি সকলের ভালবাসা এক নয়',
#  'বৃন্দাবনের কষ্টের জীবন। ',
#  'সব কিছু মেনে নিয়েও আমি আপনাকে ভালোবাসবো। ',
#  'ভবিষ্যতের কথা চিন্তা করে ভালোবাসা হয় না',
#  ' আব্দুল হামিদ দেশের মহান ব্যক্তিত্ব',
#  ' জীবন  থেকে কিভাবে যে শুক্রবার গুলো চলে গেলো ',
#  'যার মন সুন্দর,  সে অল্পতেই খুশি হয়। ',
#  'নারীরা নির্যাতনের স্বীকার এইটা নিয়ে প্রতিবাদ। ',
#  'যৌতুক না নেয়ার বেপারে ছেলেরা বাবা মাকে বোঝাতে পারে ',
#  'ভালোবাসার জন্য আত্নসম্মান ছেড়ে দিও না ',
#  'নারীরা সব করতে পারে ',
#  ' মাঝেমাঝে কিছুই ভালো লাগে না ',
#  'সেকেলে মেয়ের প্রেম ',
#  'বয়ফ্রেন্ড যখন অন্য ছেলের সাথে প্রেম করে। ',
#  'ভালোবাসার কিছু অনুভূতি ',
#  'করোনা ভাইরাসে সব কিছুর দাম বৃদ্ধি। ',
#  'পরিবার সবচেয়ে বড় জিনিস, ',
#  'ভালোবাসা লোক দেখানো নয়',
#  'খারাপ সময়ে সময় আরো খারাপ হয়ে যায়!',
#  'যা চলে যাই তার ফেরানো যাই না',
#  'আত্মসম্মান বিসর্জন দিয়ে স্বামীর সংসার করা হয়নি',
#  'ভাইয়া ডাকা মানে সব শেষ হয়ে যাবে না',
#  ' সব খারাপ মানুষের মাঝে  এখন  ও  ভালো  মানুষ  আছে',
#  ' অর্ণব আর জন্মদিন আজ ',
#  'করোনা ভাইরাস',
#  'আপনি ভুল মানুষটির সাথে আছেন, না সঠিক মানুষটির  সাথে যাচাই করুন\n',
#  'টাকা দিয়া ভালোবাসা যাই না ',
#  ' ভালোবাসা মানে এক অনুভূতি ',
#  'বিমান,হেলিকপ্টার এর সাউন্ড শুনলেই ভালো লাগে ',
#  ' ভালোবাসার কোনো কারণ লাগে না ',
#  'অনেক কষ্টের তুলনায়  ব্রেকআপ আর কষ্ট   কিছুই  না ',
#  'অন্যরা কে কি ভাবলো আসে যায় না',
#  'এমন মানুষের সাথে প্রেম করুন যে আপনার প্রতি যত্নবান হবে। ',
#  'অল্পতেই সুখ খুঁজে পাওয়া যায়।',
#  'প্রেম করার ইচ্ছা',
#  ' পাকিস্তানিদের কর্মকান্ড আগে আর এখন ',
#  '  ভালো  লাগার  অদ্ভুত কারণ ',
#  ' বাঙলী নারীর সৌন্দর্য শাড়িতে।',
#  ' ভুল মানুষের হয় তাই মানুষ নিখুঁত না',
#  ' কিছু মানুষ থাকে যাদের কিছুতেই কোনো টেনশন নেই',
#  ' বুধবার দিনে ঘটে যাওয়া কিছু কথা',
#  'কোনো কাজই ছোট নয়',
#  ' সবারই মানিয়ে নেওয়া শিখা উচিত',
#  'সারাদিন অনলাইন থাকা মানেই প্রেম করা না।',
#  'মেয়ে একটা গালি হয়ে গেছে এখন',
#  'মায়ের ভালোবাসাই নির্ভেজাল এর স্বার্থহীন।',
#  'তৃতীয় বিশ্বযুদ্ধের ভয়াবহতা বাংলাদেশে আসে পড়তে পারে',
#  'যে তোমার সাথে কথা বলতে চেয়েও কথা বলতে পারছে না তাকে ভালোবাসো ',
#  'অতীত দেখে কাউকে বিচার করো না ',
#  'একজন ধর্ষিতা মেয়েকে বিয়ে করা যাই। ',
#  ' আবারো ভালোবাসা যায়, যদি তার কাছে  নিজেকে নতুন করে পরিচয় করিয়ে দেয়া যায়। ',
#  'কেউ তোমাকে ছাড়া থাকতে পারলে তুমিও তাকে ছাড়া থাকতে পারবে। ',
#  'আল্লাহ যা দিয়েছে যথেষ্ট দিয়েছে',
#  'তুমি যা করবে তাই পাবে',
#  'দেখা না হওয়ার কষ্ট ',
#  ' মেয়েদের মন বোঝার কিছু টিপস। ',
#  'নিজের স্বপ্ন মেয়েকে দিয়ে পূরণ করা',
#  'নারীরা শুধ ধর্ষিতা হওয়ার জন্য জন্মায় না ',
#  'মানুষের চিন্তাভাবনা পরিবর্তন করা দরকার ',
#  'ধর্ষণ প্রতিনিয়ত ঘটছে ',
#  'বউ এর জন্য নিজে না খেয়ে ভাগাভাগি করে খাওয়া',
#  'মেসি সবার সেরা।',
#  'অগ্নিকান্ডের সময় উপস্থিত জনগণের করণীয়।',
#  'জ্যামের জন্য এক্সাম মিস ।',
#  'নাঈমকে টাকা দেয়া হচ্ছে ।',
#  'উজ্জ্বল অর্থের প্রয়োজনে মিথ্যা সংবাদ প্রচার করে।',
#  'হোলি খেলাটাই হল না।',
#  'একজন সাহসী পাবে তার সম্মানী ।',
#  'স্বপ্ন দেখি ইংরেজীতে একদিন অনেক ভাল করব।',
#  'সবার সামনে ইংরেজি বলতে পারছি ।',
#  'লিংকটা চাচ্ছিলাম।',
#  'জীবনকে বদলে দিয়েছে।',
#  'পারেন না দেখেই আমার গ্রুপে এসেছেন।',
#  'বাস্তবতা কে ঘৃনা করি।',
#  'কুচক্রী মহলের শাস্তি হোক।',
#  'হাইটেক পার্ক নির্মাণ কাজ হাতে নিয়েছে সরকার।',
#  'শত শত তরুন তরুণীর কর্মসংস্থা্র ব্যবস্থা হবে।',
#  'প্রতিবন্ধী মেয়েদের জন্য পরিচর্যা কেন্দ্র স্থাপন করা হবে।',
#  'বিল গেটস এবং পল অ্যালেনের উদ্যোগে প্রতিষ্ঠিত হয় মাইক্রোসফট।',
#  'মাইয়ের দৃষ্টান্তমূলক শাস্তি চাই।',
#  'ভানুয়াতুতে শ্রমিক আটকা পড়েছে।',
#  'আজকে তো স্বাধীনতা দিবস।',
#  'এক যুগ ঘুমিয়ে উঠলাম।',
#  'আজকের ল্যাবটা করা জরুরী।',
#  'আর্টিফিশিয়াল ইন্টেলিজেন্স ক্লাস হবে না।',
#  'আগুনে পুড়ে নিহত কাওছারের দুই শিশুর দায়িত্ব নেওয়া বেশি জরুরি।',
#  'পরিচিতজন খোঁজ না নেওয়া মূলত ভালোবাসা কমায়।কিন্তু সত্য হলো ভালোবাসা কখনও কমেনা।',
#  'দূর্ঘটনায় সাহায্য না করে সোশ্যাল মিডিয়ায় লাইভে আসার কালচার আমাদের।',
#  'স্বপ্ন সেটা যা মানুষকে ঘুমাতে দেয় না।',
#  'বজ্রের বিদ্যুৎ সঞ্চিত করলে সেটা হবে ইলেকট্রিসিটির আধার।',
#  'স্কাউটের ছেলেমেয়গুলো অসাধারণ উদ্যোগ দেখে নিজে থেকে ওভারব্রীজ দিয়ে পার হয়েছি।',
#  'আমি অশ্বমেধের ঘোড়া হতে চাই।',
#  'হঠাৎ মনে হচ্ছে বয়স বাড়ছে, হাজার বছরের পুরানো সেই বয়স',
#  'কাভার্ডভ্যানের ধাক্কায় ব্র\u200d্যাকের শিক্ষার্থী ফাহমিদা নিহত।',
#  'ট্রাফিক জ্যাম আমাদের জীবনের অবিচ্ছেদ্য একটি বিষয়।',
#  'কোচিং সেন্টার ব্যবসায়ীর দ্বারা শিক্ষার্থীরা হেনস্তার স্বীকার।',
#  'মিত কি মেনে নেবে মেঘ কে নাকি ভুল বুজবে|',
#  "মেশিন লার্নিং এর কল্যানে 'ফুল সেলফ ড্রাইভিং' মোড চলে আসবে আমাদের হাতের নাগালে।",
#  'সময় গেলে সময় আসবে কিন্তু জানটা শরীর থেকে বেরিয়ে গেলে আর ফিরে আসবে না।',
#  'পাটকেল হাতে নিয়াও চুপচাপ বসে আছি।',
#  'ভেতরে মানুষ জীবন-মৃত্যুর মাঝখানে আটকে আছে।',
#  'সমাজে আমি ও চিন্তা ভাবনা গুলো বেমানান।',
#  'স্বাধীনতা চাইতে চাইতে আজ তুমি পশুর খাঁচায়।',
#  'অতীতে গিয়ে তারা পাথর খুঁজে এনে আবার মারামারির প্রস্তুতি নিচ্ছে।',
#  'থেতলে যাওয়া মাথা দিয়ে ঘুমাতে কষ্ট হয়।',
#  'টপিকের সাগরে হারিয়ে যাচ্ছি।',
#  'মানসিকতার পাল্টানোর মধ্য দিয়ে পৃথিবী পাল্টে দেওয়া সম্ভব।',
#  'অঘটন এর মধ্যে একটা বাজে দিন কাটালাম।',
#  'বৃষ্টির দিনে গ্রামের বাড়িকে বেশি মিস করি।',
#  'আন্দোলন করার জন্য স্কুল কলেজ বন্ধ করার দরকার হয় না।',
#  'শিল্পীর শিল্পকর্ম মৃত্যুর মধ্যে জনপ্রিয়তা এবং চাহিদা হয়ে উঠা অনেক পুরাতন রীতি।',
#  'কথার ও রাগেরপৃষ্ঠে ঢাকা পড়লো মনের আর্তনাদ।',
#  'প্রত্যেকটা মানুষেরই কোন কিছুর প্রতি প্রবল আকর্ষণ থাক।',
#  'প্রাইভেট আর পাবলিক বিশ্ববিদ্যালয়ের পার্থক্য পরীক্ষা ও ছুটি ।',
#  'কিছু জিনিসের সৌন্দর্যটাই অন্যরকম।',
#  'ঘুমহীন চোখে ভাবছি বসে, সফল ছেলে কার?',
#  'সৌখিনতা আর বিলাসিতার জন্য ধনের প্রাচুর্যয়ের খুব একটা দরকার নেই।',
#  'এগিয়ে চলছি আর ভাবছি কখন বিশ্রামের সময় হবে।',
#  'লুকিয়ে থাকা সুপারহিরো অদ্ভূত জাদুকর।',
#  'প্রকৃতির খুব কাছে গিয়ে সময় কাটাতে ইচ্ছে করে।',
#  'পড়াশোনা বাদ,একটা ভালো গুন্ডা হবো।',
#  'পরীক্ষা আসলেই মনের মধ্যে অন্যরকম আনন্দ বিরাজ করে।',
#  'জীবনকে পরিপূর্ণভাবে উপভোগ করার জন্য একা থাকাটা খুবই জরুরী।',
#  'জীবনটাকে জটিল করার কি দরকার একটা সরল সমীকরণ মাত্র।',
#  'জমলো মেলা আমার বয়স ষোল তে প্রেম প্রেম খেলা।',
#  'আয়নাবাজি টিম গল্পটাকে যথাযথভাবে রূপ দিয়েছে।',
#  'ঘুমের পর এখনও ঘুম ছাড়া আর কিছু দেখার ইচ্ছে হচ্ছে না।',
#  'চোখের ভাষায় অভিমান হাজারো।',
#  'সত্যিকারের ভালোবাসা টা আমাকে সে অর্পণ করতে চেয়েছিল।',
#  'ধর্ম রক্ষা করার জন্য অন্যের বিরুদ্ধ্যে যুদ্ধ ঘোষনা করার দরকার নেই।',
#  'আলাদিনের জ্বীন লুকিয়ে থাকে বিশ্লেষণের মধ্যে।',
#  'পড়া শেষ হয় না।',
#  'রাগ ঝাড়ার মতো বালাই আর নাই।',
#  'আমার নিস্পাপ সন্তানের নির্মম খুনের বিচারের দাবিতে আপনাদের সমর্থন চাই।',
#  'স্বাধীনতার পর থেকে চলমান অসুস্থ ধারার রাজনীতি এখনো বহাল।',
#  'কমনসেন্সহীন মানুষগুলোর সমস্যাটা কি?',
#  'ভবিষ্যৎতে এমন ঘটনা যেন না ঘটে তাই আগে থেকেই সচেতন থাকা উচিৎ।',
#  'মানুষ উড়াও এর মাধ্যমে আকাশ পথে চলাফেরা করবে।',
#  'ড্রাইভাররা কি কখনও নিয়ম মেনে গাড়ি চালাতে পারবে না?',
#  'আমি আর নিস্পাপ চাদ সারারাত কথা বলে করেছি পার।',
#  'মাটির দেহ আবার মাটিতেই মিশে যাবে।',
#  'সবার সামনের দিনগুলা খুব ভাল কাটে।',
#  'ঘূর্ণিঝড় ফণী আয়তনে বাংলাদেশের চেয়ে বড়।',
#  'কিছু মানুষের চক্ষু লজ্জা শব্দের সাথে পরিচয় হওয়া উচিত।',
#  'আমরাও ব্যাঙের মত মানিয়ে নিচ্ছি আমাদের চারপাশের সাথে।',
#  'ভালোবাসা আলাদা জিনিস যার মাঝে কোন চাহিদা নেই।',
#  'প্রথমে জানুন কম্পিউটার ইঞ্জিনিয়ার কি নিয়ে পড়াশুনা করে এবং কি কাজ করে, তারপর কথা বলুন।',
#  'অপ্রত্যাশিত ভাবে কিছুদিন আগে ফোনটা চুরি হয়ে গিয়েছিল।',
#  'অপ্রত্যাশিত ঘটনাগুলো প্রত্যাশিতভাবে একের পর এক ঘটতে থাকে।',
#  'সবচেয়ে ভারী বস্তুটা মাথায় ভর করেছে।',
#  'প্রকৌশোলীর আয় জনগণ ও জাতির সমৃদ্ধির সাথে বৃদ্ধি পায়।',
#  'বাঁচার ইচ্ছেটা এখন আর কাজ করেনা।',
#  'নিজে সুযোগ পাইনাই তাই অন্যকেও পাইতে দিবো না।',
#  'ধন্যবাদ "নীলাম্বরী"সকালটা আমার করে দেওয়ার জন্য।',
#  'পর্দার গল্পের পিছনেই একটা সত্য গল্প লুকায়িত থাকে যা চোখের আড়ালেই নিঃশেষ হয়ে যায় ।',
#  'অর্থ না বুঝে কখনো কারো বেস্ট ফ্রেন্ড হওয়ার চেষ্টা করো না।',
#  'আমি কিন্তু মজনু বা ফরহাদ না।',
#  'কারো প্রতি মায়া বাড়াতে নেই।',
#  'এক্সপেকটেশন থেকে বেশিই পাইছি মুভিটা থেকে।',
#  'অভিধানে শেষ বলে কোন শব্দ নাই।',
#  'তুই তো এখন আমার না।',
#  'নির্বোধ হয়ে গেছি আমরা',
#  'ঠাডা পড়ুক সবার উপর।',
#  'ভালো লাগা আর ভালোবাসা এক নয়।',
#  'জীবনে কি এমন পূন্য করেছি আল্লাহ আমাকে এত্তোটা সাহায্য করে।',
#  'আমার কাছে কাল শুধুই রবিবার।',
#  'ইঞ্জেকশন কে ভয় পায়।',
#  'কুলখানি না কারো বিয়া খাইতে আসছে।',
#  'মানুষ জন এর উপকার করতে চাইলে ভাত নাই।',
#  'কটুর জন্য ছেলে হয়ে গেছে।',
#  'নিজে কোনো কিছু করার মাঝে যে সুখ তা অন্যের মাধ্যমে পাওয়া যায় না।',
#  'পোলা গো কইলজা এত্ত বড়।',
#  'আমার ভাষা নাই।',
#  'বিরিয়ানি লাভারদের কথা কেউ মাথায় রাখলো নাহ।',
#  'বিয়ে করে ঘর জামাই রাখে।',
#  'মানুষ রে কষ্ট দিয়ে লাভ টা কি?',
#  'আমার টাকা গুলান বাঁচতো।',
#  'গুজব ভাবিয়া বিভ্রান্ত হবেন না।',
#  'সবাইকে চলে যেতে দেয়া উচিৎ।',
#  'অনের বড় হ তোরা।',
#  'একদিন নিজের একটা পরিচয় হবে।',
#  'লাখ টাকা খরচ করে বিদেশে ঘুরতে যাই।',
#  'সীতাকুন্ডের সবচেয়ে দুর্গম ভয়ংকর ঝর্ণা হচ্ছে সোনাইছড়ি।',
#  'নৌবাহিনীর সক্ষমতা আরো বৃদ্ধি করবে।',
#  'প্রধানমন্ত্রী ক্ষতিগ্রস্তদের সহায়তার নির্দেশ প্রদান করেছেন।',
#  'অনুশোচনা ছাড়া আর কিছুই করার থাকবে না।',
#  'মুশফিক কেন "জিরো" রানে আউট হলো।',
#  'রিটেক নিতে কলিজা লাগে।',
#  'কেউ কারো সম্পত্তি নয়।',
#  'দাদীকে খুব মিস করি।',
#  'সুন্দর অতীত খুব ভোগায়।',
#  'ভালোবাসা মানে অমরত্ব',
#  'সঠিক বন্ধু নির্বাচন করুন।',
#  'মেয়েরা দুই ধরনের হয়।',
#  'খালি নাচবো আর খাবো।',
#  'পানামা যাওয়ায় আমি খুশি।',
#  'নারীরা সবসময় পুরুষ থেকে ক্ষমতাবান।',
#  'অসাধারণ মানুষের চিন্তা গুলো।',
#  'আপনি জীবন্ত কিংবদন্তী।',
#  'নিজেকে গড়ে তোলার নাম সফলতা।',
#  'এরা ছাত্র না বহিরাগত।',
#  'তোমাকে পেরিয়ে চলে যাচ্ছি।',
#  'লোকাল বাসের মতো বাংলাদেশ ক্রিকেট দল।',
#  'উপভোগে ও প্রকৃতির অভিযোগ নাই।',
#  'ক্যাসিনো আর শেয়ার বাজার দুইটাই জুয়া।',
#  '১০ কোটি টাকা গুনতে দেওয়া হোক।',
#  'বাংলাদেশে ভালো ছেলে নাই।',
#  'অবশেষে বাংলাদেশ পেলো লেগ স্পিনার।',
#  'ঘরে বসে দূরে কাউকে জ্বালিয়ে মারার মতো মজা আর কোথাও নেই।',
#  'কমের কাছে থাকার আকুতি।',
#  'খেলা দেখে আত্মবিশ্বাস কমে যাবে।',
#  'পৃথিবীতে যত কিছু মহৎ আর কল্যাণ কর , অর্ধেক করিয়াছে নারী , অর্ধেক তার নর ।',
#  'মানবিক দৃষ্টিতে তি\u200cন্নি দা\u200cশকে একটি বিভাগে ভর্তি করানো।',
#  'কাউকে নিয়ে কিছু লেখা কঠিন ব্যাপার।',
#  'নোয়াখালীবাসী তাদের সাধ্য মতো চেষ্টা করে',
#  'সবাই কাবাডি খেলায় মন দে।',
#  'নম্বর আনব্লক করার প্রয়োজন নাই।',
#  'প্রাইভেটে পড়েও বেঁচে থাকো।',
#  'স্ট্যাটাস টা ভারত বিরোধী।',
#  'দোষ দেয়া সোজা',
#  'এই যুবকেরাই আগারওয়াল',
#  'জাজ করতে যাওয়াটা বোকামী।',
#  'আমাকে ঘুষ দিতে চেয়েছিলো।',
#  'দেখেই হয়তো চেনা যায়।',
#  'পেয়েছি একটা ব্যাতিক্রমী গল্প।',
#  'এক প্লেট সাদা চকচকে ভাত।',
#  'বিচারের রায়কে শ্রদ্ধা করো।',
#  'মানুষ কত খারাপ।',
#  'এটা তো তোমার দোষ।',
#  'তিনি আবারও ক্ষমতায় আসছেন।',
#  'যার ন্যুনতম ধারনা নেই।',
#  'সভা, সমাবেশ করতে দেওয়া উচিত।',
#  "আরো দু'টি মেট্রোরেল হচ্ছে ঢাকায়।",
#  'টাইম মেশিন আছে।',
#  'ট্রিট নয় ট্রিটমেন্ট চাই।',
#  ...]

# %%
summarize("মানুষের মুখ খুব শ ক্তিশালী এক জিনিস। মানুষ যেটা বলে সেটার একটা প্রভাব আছে।অভিজ্ঞতা থেকে দেখেছি একটা ছেলেকে ক্ষেপানোর জন্য বলা হতো, অমুক মেয়ের সাথে তুই প্রেম করিস। কদিন পরে সত্যি সত্যি তারা প্রেম করা শুরু করে দিয়েছিল।স্বামী-স্ত্রীর মনোমালিন্যর সময় হয়ত স্ত্রী আফসোস করে বলল, আমি পুরোনো হয়ে গেছি - এখন তো আর আমাকে ভালো লাগবে না।সত্যি সত্যি দেখা যাবে কদিন পরে স্বামীর ঠিক ওই জিনিসটাই মনে হতে থাকবে। অথচ হয়ত সে এ ব্যাপারে আগে ভাবেইনি।একটা ছেলেকে পরিবারের সবাই বলে, তুই কোনো কাজের না - দেখা যাবে ছেলেটা আসলেই কিছু করতে পারছে না।এজন্য রসুল সাল্লাল্লাহু আলাইহি ওয়া সাল্লাম বলেছেন, হয় ভালো কথা বলো নয়ত চুপ থাক।আমাদের জীবনের বহু ভালো পরিস্থিতি খারাপ থেকে খারাপ হয়েছে শুধুমাত্র আমাদের কথার কারণে।জিহবা সাবধান ভাইয়েরা। মুখ সাবধান বোনেরা।রসুল সাল্লাল্লাহু আলাইহি ওয়া সাল্লামের কথাটাকে দাম দিই - সংসারে শান্তি আসবে, আয়ে বারাকাহ আসবে।")
# Out:
# 'ভালো কথা বল নয়ত চুপ থাকো'

# %%
summarize("ক্লাসে সবচেয়ে দূর্বল ছেলেটি কাল সমাবর্তনে এসেছিল সবার চেয়ে হাই পজিশনের জব নিয়ে। বারবার প্রেমে ব্যর্থ হওয়া মেয়েটি এসেছিল একটি সুন্দর ছোট্ট পরিবার নিয়ে। কারো কাছে পাত্তা না পাওয়া, তোকে দিয়ে কিছু হবে না বলা ছেলেটিই সবচেয়ে সুন্দর বউ নিয়ে এসেছে। পড়াশোনার খরচ যোগাতে টিউশন করে হাত খরচ চালানো মেয়েটি কাল গাড়ি দিয়ে ক্যাম্পাসে এসেছিল। ক্লাসের সবচেয়ে সাক্সেস্ফুল ছেলেটি ডিপ্রেশনে ভুগছে জব না পাওয়ায়। ডিপার্টমেন্টের হার্টথ্রোব মেয়েটির চোখে নিচে কালি বিয়ে হচ্ছে না বয়স হয়ে গেছে।এভাবেই সময়ের সাথে বদলে যায় মানুষের জীবনে ইকুয়েশন। আসলে সমাবর্তনের মাধ্যমে শিক্ষা জীবনের শেষ হলেও সফলতা ও ব্যর্থজীবনের হিসাব গণনা শুরু হয়ে এখান থেকেই।তাই ঘৃণা, হিংসা, কম্পিটিশন বাদ দিয়ে জীবনটাকে বাচা উচিত সম্পূর্ণ স্বাদ ও ভালবাসা নিয়ে। কখন জীবনের কোন মোড় দেখায় কোন নিশ্চয়তা নেই, তাই কোন মুহূর্তের জন্য যাতে আফসোস না থাকে।")
# Out:
# 'সমাবর্তনের মাধ্যমে শিক্ষা জীবনের শেষ হলেও সফলতা ও ব্যর্থজীবনের হিসাব গণনা শুরু হয়ে এখান থেকেই'

# %%
summarize("ইতালির প্রধানমন্ত্রী জুসেপ্পে কন্তে বলেছেন, একেকজন বাংলাদেশি একেকটা ভাইরাস বোমা। অনেক বাংলাদেশি ভাই সেটাকে শেয়ার করে দেশকে পরোক্ষভাবে তিরস্কার করছেন। অথচ কন্তে সাহেবকে বলা দরকার, আমাদের অসচেতনতা নিয়ে এমন ঢালাও মন্তব্য করার আগে আপনার অগ্রজ শাসকদের দিকে তাকান। নিরো সাহেবের দিকে তাকান।আপনি কী জানেন না? রোম যখন পুড়ছিলো, নিরো তখন সাহেব বাঁশি বাজাচ্ছিলেন।আর আমরা একটু বাঁশি বাজালেই দোষ...")
# Out:
# 'করোনা ভাইরাস মোকাবিলায় সবার সচেতন থাকতে হবে পাশাপাশি আল্লাহর ইবাদাত করতে হবে।'

# %%
summarize("মুক্তির সারথি বাংলাদেশ সাধারণ ছাত্র অধিকার সংরক্ষণ পরিষদ আমাদের দেশে স্বাধীনতার পর থেকে চলমান অসুস্থ ধারার রাজনীতি এখনো বহাল তবিয়তে চলছে। এই অবস্থা থেকে বের হয়ে আসতে না পারলে দেশ ও জাতি আরো গভীর অন্ধকারে নিমজ্জিত হবে। একটি দেশের প্রকৃত উন্নয়ন নির্ভর করে সেদেশের রাজনৈতিক স্থিতিশীলতার উপর। দেশে দৃশ্যমান উন্নয়ন অনেক কিন্তু প্রকৃত উন্নয়ন কতটা তা যতেষ্ঠ প্রশ্নের মুখোমুখি আজ। উল্টো দেশের স্তম্ভ গুলো দিনকে দিন দুর্বল থেকে দুর্বলতর করা হচ্ছে। আইন বিচার এবং শাসন বিভাগের অবস্থা বড্ড নাজুক। এখন অনেক সময় দেখি মহান জাতীয় সংসদ কোরাম সংকটে ভুগে। সাংবিধানিক প্রতিষ্ঠান গুলো তাদের স্বকীয়তা হারাচ্ছে অনবরত। বাংলাদেশ নির্বাচন কমিশন, দুর্নীতি দমন কমিশন সহ সাংবিধানিক প্রতিষ্ঠানগুলোকে এখন আর কার্যকর তেমন কোন পদক্ষেপ নিতে দেখি না আর আমরা।রাষ্ট্রের চতুর্থ স্তম্ভ গণমাধ্যম, এই গণমাধ্যমের অবস্থা যে খুব একটা ভাল তাও কিন্তু নয়। তবুও বলবো সব মিলিয়ে এগিয়ে যাচ্ছে প্রিয় স্বদেশ। আগামীতে গণমানুষের প্রত্যাশা পূরণে কাজ করে যাবে ছাত্রসমাজের প্রাণের স্পন্দন বাংলাদেশ সাধারণ ছাত্র অধিকার সংরক্ষণ পরিষদ দেশ ব্যাপি কমিটি হালনাগাদের কার্যক্রম চলমান রয়েছে, আপনি আছেন তো আপনার জেলার কমিটিতে....??যুক্ত না থাকলে এখনি সময় যুক্ত হওয়ার। আপনাদের হাত ধরেই পরিবর্তন আসবে ইনশাআল্লাহ।।")
# Out:
# 'এই প্রজন্ম থেকে কোনো বুদ্ধিজীবী পাওয়া কঠিন।'

# %%
# !pip install rouge
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /data/user/home/arabby/.conda/envs/tf/lib/python3.9/site-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
from rouge import Rouge

# %%
hypothesis = "স্বাধীনতার পর থেকে চলমান অসুস্থ ধারার রাজনীতি এখনো বহাল।"
reference = "স্বাধীনতার পর থেকে চলমান অসুস্থ ধারার রাজনীতি এখনো বহাল।"

rouge = Rouge()
scores = rouge.get_scores(hypothesis, reference)
print(scores)
# Out:
# [{'rouge-1': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-2': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-l': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}}]
